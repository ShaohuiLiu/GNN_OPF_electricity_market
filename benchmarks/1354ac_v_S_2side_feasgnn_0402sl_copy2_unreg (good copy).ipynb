# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import time
import math
root=''
try:
  from google.colab import drive
  drive.mount('/content/drive')
  root='./drive/MyDrive/gnn/data/'
except:
  pass
device='cuda' if torch.cuda.is_available() else 'cpu'
print(torch.cuda.get_device_name(0))
# Out:
# Quadro RTX 5000

# %%
torch.cuda.empty_cache()

# %%
filename=root+'data_1354ac_2022/ieee1354_ISF.txt'
S_isf=pd.read_table(filename,sep=',',header=None).to_numpy() # ISF matrix
filename=root+'data_1354ac_2022/ieee1354_fmax.txt'
f_max=pd.read_table(filename,sep=',',header=None).to_numpy() # flow limit
n_line = np.size(S_isf,0)
S = torch.from_numpy(S_isf).to(device) # ISF
f_max = torch.from_numpy(f_max).to(device) # flow limit
print(S.shape,f_max.shape,torch.min(f_max))

x=np.load(root+'data_1354ac_2022/ac1354_x_04022022.npy')
y=np.load(root+'data_1354ac_2022/ac1354_y_04022022.npy')
W=np.load(root+'data_1354ac_2022/ac1354_w.npy')
print(x.shape,y.shape)
print(np.max(x),np.min(x),np.max(y),np.min(y))

# scaling on voltage
vy_deviation = 0.8
vy_scale = 1000
y[:,1,:] = (y[:,1,:] - vy_deviation) * vy_scale
print('voltage range(scaled):',np.min(y[:,1,:]),np.max(y[:,1,:]))

# scaling on price
pi_deviation = 150
y[:,0,:] = y[:,0,:] + pi_deviation


# filter out extreme points in price
y_sort_arg = np.argsort(np.amax(np.abs(y[:,0,:]),axis=0)) # max extreme
y_sort_arg1 = np.argsort(np.amin(y[:,0,:],axis=0),axis=0) # min extreme

del_idx0 = []
del_num = 500
for i in range(del_num):
  del_idx0.append(y_sort_arg[-i])
  del_idx0.append(y_sort_arg1[i])
print(del_idx0)
del_idx = [] # keep only non-repeated
[del_idx.append(x) for x in del_idx0 if x not in del_idx]
del_idx = np.sort(del_idx)
# delete extreme points
print('price range old:',np.min(y[:,0,:]),np.max(y[:,0,:]))
print('voltage range old:',np.min(y[:,1,:]),np.max(y[:,1,:]))
x = np.delete(x, del_idx, axis=2)
y = np.delete(y, del_idx, axis=2)


# generate training/test dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x.transpose(),y.transpose(),test_size=0.2, random_state=18)
x_train=x_train.transpose()
x_test=x_test.transpose()
y_train=y_train.transpose()
y_test=y_test.transpose()
print('Training data size:',x_train.shape)
print('Training label size:',y_train.shape)

class Dataset(torch.utils.data.Dataset):
    def __init__(self, features, labels, device='cpu'):
        self.features=torch.from_numpy(np.transpose(features)).float().to(device)
        self.labels=torch.from_numpy(np.transpose(labels)).float().to(device)
    def __len__(self):
        return len(self.features)
    def __getitem__(self, idx):
        if torch.is_tensor(idx): idx = idx.tolist()
        # Select sample
        X = self.features[idx]  # shape = (24,)
        y = self.labels[idx]    # shape = (24,)
        X = torch.reshape(X,(6,1354))
        y = torch.reshape(y,(2,1354))
        return X, y
params = {'batch_size': 256,
          'shuffle': True,
          'num_workers': 0}
# Dataset Generators
training_set = Dataset(features=x_train,labels=y_train,device=device)
training_generator = torch.utils.data.DataLoader(training_set,**params)
validation_set = Dataset(features=x_test,labels=y_test,device=device)
validation_generator = torch.utils.data.DataLoader(validation_set,**params)

print('price range new:',np.min(y[:,0,:]),np.max(y[:,0,:]))
print('voltage range new:',np.min(y[:,1,:]),np.max(y[:,1,:]))
# Out:
# torch.Size([1991, 1354]) torch.Size([1991, 1]) tensor(281., device='cuda:0', dtype=torch.float64)
# (1354, 6, 9974) (1354, 2, 9974)
# 5864.5 -2123.9 5178.4 -4855.3
# voltage range(scaled): 99.99999999999997 333.89999999999986
# [5202, 5331, 6839, 9322, 8889, 7576, 2333, 7126, 8493, 56, 8004, 8323, 7345, 4893, 2972, 932, 5720, 5228, 1179, 9099, 5331, 213, 7915, 2303, 3666, 8580, 8304, 5235, 1072, 4980, 4694, 549, 1666, 9749, 5898, 9527, 9657, 2436, 463, 6632, 5129, 1710, 4153, 1740, 106, 4845, 7424, 5418, 4923, 7202, 4413, 4027, 5959, 1240, 9776, 5788, 4961, 2089, 6513, 7990, 7508, 9501, 9562, 9639, 1746, 5246, 4179, 5013, 582, 3976, 3084, 9096, 7798, 5416, 3647, 1393, 9887, 9854, 861, 5709, 2089, 3223, 5803, 469, 359, 4940, 4341, 7348, 2071, 796, 2728, 7877, 4799, 8613, 8785, 8814, 6668, 6037, 420, 7507, 6516, 4756, 4029, 8483, 9794, 1898, 2121, 8944, 7573, 6260, 5132, 3225, 9622, 5127, 2913, 4759, 218, 6017, 16, 1967, 8427, 8351, 6316, 6342, 1844, 5909, 6343, 6424, 3648, 3683, 4012, 4952, 7772, 5097, 3360, 2414, 5727, 1726, 4546, 4826, 3563, 2247, 8909, 4609, 2996, 8121, 2840, 6387, 2751, 673, 546, 7704, 3937, 6741, 3317, 9363, 1480, 6969, 4568, 1747, 4061, 390, 3327, 3467, 9486, 8553, 7679, 651, 2527, 1899, 5965, 9381, 3668, 8205, 5613, 786, 3297, 7034, 9397, 6869, 3187, 3909, 9270, 7115, 9512, 4822, 4544, 5814, 9147, 3522, 5001, 9129, 1388, 7354, 7462, 9469, 1750, 1321, 4519, 966, 3239, 5395, 7341, 7204, 8506, 6670, 5680, 867, 2724, 4473, 9327, 1358, 8112, 1194, 2120, 6611, 7326, 7081, 2503, 186, 7126, 7611, 4066, 5846, 6561, 6078, 5895, 5676, 9506, 2990, 9185, 7822, 2335, 1744, 999, 613, 1356, 6083, 2593, 6888, 1576, 5422, 7972, 151, 9342, 3200, 7243, 5919, 3130, 2019, 7963, 9280, 5927, 168, 471, 3433, 7442, 2671, 3858, 7821, 6676, 2745, 9500, 6653, 7139, 8163, 2246, 7816, 7939, 676, 3006, 2402, 774, 7345, 8542, 9367, 7950, 6881, 1710, 9056, 3811, 8410, 9597, 7944, 8964, 5935, 8149, 8817, 1170, 4738, 1790, 8296, 4250, 236, 3842, 6248, 6413, 3047, 2443, 3984, 3519, 5916, 9187, 3339, 8361, 3734, 4529, 3900, 3868, 9956, 9083, 3495, 9042, 4854, 3178, 9542, 9706, 4416, 2474, 9673, 6755, 822, 3769, 6431, 3779, 2335, 1021, 753, 5846, 6871, 5713, 8898, 9260, 5959, 2588, 9044, 8541, 7424, 1479, 8882, 3786, 4793, 2418, 2505, 9138, 8762, 2045, 5420, 9021, 1258, 9074, 1847, 6129, 3380, 125, 6803, 6000, 5336, 4641, 8407, 3795, 5210, 3867, 9278, 8182, 2586, 7415, 2398, 2583, 7022, 9753, 129, 5385, 3060, 6473, 6675, 965, 3910, 6777, 285, 3472, 9636, 9413, 1880, 9099, 4301, 7469, 1957, 5134, 9457, 9041, 1095, 5804, 4548, 1373, 2742, 5078, 4721, 7062, 1058, 5105, 2397, 9715, 5763, 6798, 8824, 5456, 3247, 8884, 7589, 7116, 7826, 4056, 8775, 5172, 8345, 4761, 6597, 8437, 1701, 1725, 4723, 9862, 7936, 6014, 8988, 4347, 4013, 175, 4642, 3363, 7728, 4872, 4358, 6880, 5878, 4771, 6702, 5629, 9722, 3516, 2287, 8309, 4977, 8539, 8413, 6906, 5640, 4802, 6289, 8644, 4628, 1980, 9416, 5562, 1424, 6091, 280, 657, 7143, 7448, 4572, 2604, 7696, 9627, 6972, 687, 1013, 538, 5665, 7897, 876, 9496, 8479, 7579, 9838, 280, 3449, 9411, 914, 4609, 8099, 9843, 465, 2820, 6202, 3204, 2196, 4329, 2885, 1563, 5190, 6251, 2874, 2397, 8015, 6137, 6466, 8845, 7604, 8463, 1973, 1871, 9281, 5476, 6048, 6630, 2600, 4760, 6802, 7750, 741, 4009, 9894, 9003, 8267, 3522, 1791, 364, 9520, 6614, 6293, 4157, 7008, 8351, 8965, 4010, 3710, 8413, 2282, 6256, 3269, 9710, 1713, 3346, 4655, 5768, 4088, 6696, 7923, 1724, 4180, 8454, 898, 499, 5940, 1845, 6238, 9777, 5539, 7231, 9516, 4948, 6439, 8466, 8881, 9493, 7406, 8377, 5479, 8688, 9794, 1101, 9185, 127, 635, 3046, 2876, 1815, 545, 6230, 9021, 5079, 1006, 7199, 2331, 9707, 8399, 3945, 9618, 9745, 3155, 7692, 8498, 4695, 2746, 3877, 542, 5151, 7994, 6800, 1752, 3474, 9, 6601, 7870, 2013, 1606, 5433, 3862, 2586, 6581, 3434, 2195, 7460, 247, 166, 362, 2904, 5396, 8538, 112, 1612, 8718, 8215, 1449, 7564, 6236, 1670, 5635, 236, 2801, 895, 3, 222, 2005, 451, 1253, 1441, 5302, 596, 216, 2378, 7830, 9590, 3340, 6243, 1978, 3949, 5949, 8015, 5471, 6088, 1545, 267, 3153, 1265, 8935, 7577, 4234, 3585, 8481, 8878, 6671, 7905, 4401, 8479, 7836, 7783, 8384, 7771, 1107, 2015, 9452, 2927, 6462, 8956, 895, 6861, 3473, 7797, 7599, 2705, 4148, 3613, 324, 6113, 2733, 8483, ...
# price range old: -4705.3 5328.4
# voltage range old: 99.99999999999997 333.89999999999986
# Training data size: (1354, 6, 7224)
# Training label size: (1354, 2, 7224)
# price range new: 27.810000000000002 1295.7
# voltage range new: 147.96999999999994 333.89999999999986

# %%
# # (1354, 2, 7912)
# y_sort0 = np.sort(np.amax(np.abs(y[:,0,:]),axis=0))
# y_sort_arg = np.argsort(np.amax(np.abs(y[:,0,:]),axis=0))
# print(y_sort0[-22:-1],y_sort0[-1],y_sort0)
# print(y_sort_arg)

# %%
# y_sort1 = np.sort(np.amin(y[:,0,:],axis=0))
# y_sort_arg1 = np.argsort(np.amin(y[:,0,:],axis=0),axis=0)
# print(y_sort1[:20])
# print(y_sort_arg1)
# # print(np.min(y[:,0,:]))

# del_idx0 = []
# for i in range(11):
#   del_idx0.append(y_sort_arg[-i])
#   del_idx0.append(y_sort_arg1[i])
# # y_sort_arg[-22:-1].append(y_sort_arg[-1])
# print(del_idx0)
# del_idx = [] # keep only non-repeated
# [del_idx.append(x) for x in del_idx0 if x not in del_idx]
# del_idx = np.sort(del_idx)
# print(del_idx)

# %%
# y1 = np.delete(y, del_idx, axis=2)
# print(y.shape,y1.shape)
# print('price range:',np.min(y[:,0,:]),np.max(y[:,0,:]))
# print('price range new:',np.min(y1[:,0,:]),np.max(y1[:,0,:]))

# %%
fig2 = plt.figure(figsize=(16, 8))
flat_list = list(np.concatenate(y[:,1,:]).flat)
flat_list3 = list(np.concatenate(y[:,0,:]).flat)
plt.subplot(1,2,1)
plt.hist(flat_list,bins = 100,label = 'voltage')
plt.subplot(1,2,2)
# plt.hist(flat_list3,range=[-2000, 2000],bins = 100,label = 'price')
plt.hist(flat_list3,bins = 100,label = 'price')
plt.show()

# %% [markdown]
# * Normalize the power of Laplacian

# %%
W1 = W.copy()
W1 = np.asarray(W1)
# print(np.asarray([[2,3],[4,7]])/5)
W1 = W1 / 1
W2 = W1.copy()
print(type(W))
lam,v = np.linalg.eig(W1)
print(lam[0])
for i in range(5):
  W1 = np.matmul(W1,W2) / np.max(np.matmul(W1,W2))
  # print(W1)
  lam,v = np.linalg.eig(W1)
  print(lam[0])#/10**(i+1))
# Out:
# <class 'numpy.ndarray'>
# (3+0j)
# (0.08181818181818182+0j)
# (0.022314049586776866+0j)
# (0.006085649887302784+0j)
# (0.0016597226965371218+0j)
# (0.00045265164451012446+0j)

# %%
def numparam(in_feats,out_feats): return 4*476+in_feats*out_feats+out_feats
indexes=[1,10,15,15,10,10,1]
total=0
for temp in range(len(indexes)-1):
  total+=numparam(indexes[temp],indexes[temp+1])
print(total)
# Out:
# 12130

# %%
from torch.autograd import Variable
# One layer Graph convolution from nodes to edges
class Graph_convolution_v2v_W(nn.Module):
    def __init__(self,in_features,out_features,W,n,bias=True):
        super(Graph_convolution_v2v_W,self).__init__()
        self.register_buffer('w',torch.from_numpy(W.transpose()).float())
        self.register_buffer('n0',torch.tensor(n))
        self.mapping=nn.Parameter(torch.Tensor(n,W.shape[0],W.shape[1]))
        torch.nn.init.xavier_uniform_(self.mapping.data)
        self.scale0=nn.Parameter(torch.Tensor(out_features,in_features))
        torch.nn.init.xavier_uniform_(self.scale0.data)
        self.scale=nn.Parameter(torch.Tensor(n-1,out_features,out_features))
        torch.nn.init.xavier_uniform_(self.scale.data)
        self.bias=nn.Parameter(torch.Tensor(out_features,1))
        torch.nn.init.xavier_uniform_(self.bias.data)

    def forward(self,input):
        h=torch.mul(self.mapping[0,:,:],self.w) # element-wise
        h=torch.matmul(input,h) # transpose due to batch generator
        h=torch.matmul(self.scale0,h)
        for i in range(self.n0 - 1):
          W1 = torch.matrix_power(self.w,i+2)/torch.max(torch.matrix_power(self.w,i+2))
          h1=torch.mul(self.mapping[i,:,:],W1)
          h=torch.matmul(h,h1) # transpose due to batch generator 
          h=torch.matmul(self.scale[i,:,:],h)
        return h+self.bias 

# GNN using DGL v2v graph convolution and our own v2e graph convolution
class GCN(nn.Module):
    def __init__(self, in_feats, hidden_size, W, num_bus, n_hop):
        super(GCN, self).__init__()
        self.conv_v2v1=Graph_convolution_v2v_W(in_feats,hidden_size[0],W,n_hop)
        self.conv_v2v2=Graph_convolution_v2v_W(hidden_size[0],hidden_size[1],W,n_hop)
        self.conv_v2v3=Graph_convolution_v2v_W(hidden_size[1],hidden_size[2],W,n_hop)
        self.conv_v2v4=Graph_convolution_v2v_W(hidden_size[2],hidden_size[3],W,n_hop)
        self.conv_v2v5=Graph_convolution_v2v_W(hidden_size[3],hidden_size[4],W,n_hop)
        self.conv_v2v6=Graph_convolution_v2v_W(hidden_size[4],hidden_size[5],W,n_hop)
        # self.conv_v2v7=Graph_convolution_v2v_W(hidden_size[5],hidden_size[6],W,n_hop)
        # self.conv_v2v8=Graph_convolution_v2v_W(hidden_size[6],hidden_size[7],W,n_hop)
        self.lin_output = nn.Linear(num_bus,num_bus)
         
    def forward(self, inputs):
        # m = nn.ELU()
        # m = nn.LeakyReLU()
        # m = nn.Tanh()
        m = nn.ReLU()
        h=self.conv_v2v1(inputs)
        h=m(h)
        h=self.conv_v2v2(h)
        h=m(h)
        h=self.conv_v2v3(h)
        h=m(h)
        h=self.conv_v2v4(h)
        h=m(h)
        h=self.conv_v2v5(h)
        h=m(h)
        h=self.conv_v2v6(h)
        h=torch.relu(h)
        h = self.lin_output(h)
        # time.sleep(5)
        return h
n_bus=x.shape[0]
# w_params=[10,15,10,1]
w_params=[5,10,10,5,5,2]
n_hop = 2
# W = W / 10 # normalize
net=GCN(6,w_params,W,n_bus, n_hop) # Laplacian
net=net.to(device)

# set loss_func & optimizer

# optimizer=torch.optim.Adam(net.parameters(),lr=0.01)
optimizer=torch.optim.Adam(net.parameters())
loss_optm=[]
loss_val=[]
print(net)
print('number of params: %d'%(sum(temp.numel() for temp in net.parameters() if temp.requires_grad)))
# Out:
# GCN(
#   (conv_v2v1): Graph_convolution_v2v_W()
#   (conv_v2v2): Graph_convolution_v2v_W()
#   (conv_v2v3): Graph_convolution_v2v_W()
#   (conv_v2v4): Graph_convolution_v2v_W()
#   (conv_v2v5): Graph_convolution_v2v_W()
#   (conv_v2v6): Graph_convolution_v2v_W()
#   (lin_output): Linear(in_features=1354, out_features=1354, bias=True)
# )
# number of params: 23835043

# %%
# Number of parameters in net
n_params = 0
n_params_trainable = 0
for temp in net.parameters():
    # print(temp.shape[0])
    # print(temp.shape)
    n_params += temp.numel()
    if abs(temp.shape[0] - n_bus) > 0:
      n_params_trainable += temp.shape[0] * temp.shape[1]
    else:
      n_params_trainable += n_bus + 2 * n_line
print('Number of GNN parameters:',n_params)
print('Number of effective GNN parameters:',n_params_trainable)
# Out:
# Number of GNN parameters: 23835043
# Number of effective GNN parameters: 27259

# %%
# threshold function for p_g
class my_gen_pred_binary(nn.Module):
  def __init__(self):
    super(my_gen_pred_binary,self).__init__()
  def forward(self,x,thresh):
    right_thresh=thresh.clone().detach().requires_grad_(True).double()
    left_thresh=torch.tensor(0).double()
    x=x.double()
    output = torch.sigmoid(left_thresh - x)
    output = torch.mul(output,left_thresh - x) + x
    output = torch.sigmoid(output - right_thresh)
    output = torch.mul(output,output - right_thresh) + right_thresh
    return output

# %%
## params needed for S calculation
# line parameters
filename1 = root+'data_1354ac_2022/ieee1354_lineloc.txt'
filename2 = root+'data_1354ac_2022/ieee1354_lineparams_tap.txt'
filename3 = root+'data_1354ac_2022/ieee1354_Bbus.txt'
filename4 = root+'data_1354ac_2022/ieee1354_ieee1354_J1.txt'
filename5 = root+'data_1354ac_2022/ieee1354_ieee1354_theta_nominal.txt'
filename6 = root+'data_1354ac_2022/ieee1354_ieee1354_pinj_nominal.txt'
# incidence info
line_loc = pd.read_table(filename1,sep=',',header=None).to_numpy()
# r, x, shunt, S_max
line_params = pd.read_table(filename2,sep=',',header=None).to_numpy()
B_mat=pd.read_table(filename3,sep=',',header=None).to_numpy()
# params for fast decoupled power flow
J_pf=pd.read_table(filename4,sep=',',header=None).to_numpy()
theta0_nominal=pd.read_table(filename5,sep=',',header=None).to_numpy()
pinj0_nominal=pd.read_table(filename6,sep=',',header=None).to_numpy()

# remove transformers
n_line = 1751 # the rest are trabsformers
line_loc = line_loc[:n_line,:].copy()
line_params = line_params[:n_line,:].copy()

B_r = np.delete(B_mat,639,axis=0) # ref bus
B_r = np.delete(B_r,639,axis=1)
Br_inv = np.linalg.inv(B_r)
R_line = line_params[:,0].copy()
X_line = line_params[:,1].copy()
B_shunt = line_params[:,2].copy()
Z_line = R_line + 1j * X_line 
Y_line = 1 / Z_line
G_line = np.real(Y_line)
B_line = np.imag(Y_line)
a = np.ones(n_line)
f_max = f_max[:n_line,:]
print(f_max.shape)

Jpf_inv = np.linalg.inv(J_pf)
theta0_nominal = theta0_nominal/180*math.pi
# pinj0_nominal already in p.u.

# params to tensor and GPU
G_line_tensor = torch.from_numpy(G_line).to(device) # conductance
B_line_tensor = torch.from_numpy(B_line).to(device) # susceptance
B_shunt_tensor = torch.from_numpy(B_shunt/2).to(device) # conductance
Br_inv_tensor = torch.from_numpy(Br_inv).to(device) # reduced Bbus matrix
a_tensor = torch.from_numpy(a).double().to(device) # line/transformer
W_tensor = torch.from_numpy(W).float().to(device)
Jpf_tensor = torch.from_numpy(Jpf_inv).to(device) # FDPF Jacobian
theta0_tensor = torch.from_numpy(theta0_nominal).to(device) # nominal angle
pinj0_tensor = torch.from_numpy(pinj0_nominal).to(device) # p_inj 

vy_scale_tensor = torch.from_numpy(np.asarray(vy_scale)).double().to(device)
vy_deviation_tensor = torch.from_numpy(np.asarray(vy_deviation)).double().to(device)
pi_deviation_tensor = torch.from_numpy(np.asarray(pi_deviation)).double().to(device)

print(line_loc.shape,line_params.shape)
print(np.max(line_params[:,4]),line_params[1750,4])
# Out:
# torch.Size([1751, 1])
# (1751, 2) (1751, 5)
# 0.0 0.0

# %%
class loss_func:
    def __init__(self,s_max,G_line,B_line,B_shunt,Br_inv,a,line_loc,Jpf,theta_n,pinj0,vy_scale,vy_deviation,pi_deviation):
      self.s=s_max
      self.g=G_line
      self.b=B_line
      self.c=B_shunt
      self.r=Br_inv
      self.a=a
      self.J1=Jpf
      self.t0=theta_n
      self.p0=pinj0
      self.vy_s=vy_scale
      self.vy_d=vy_deviation
      self.vy_pd=pi_deviation
      self.mse=nn.MSELoss() # MSE loss
      # hyper params for loss items
      self.lmda1=torch.tensor(10).to(device) # V MSE 
      self.lmda2=torch.tensor(1).to(device) # pi MSE 
      self.lmda3=torch.tensor(1).to(device) # v l_inf
      self.lmda4=torch.tensor(1).to(device) # s feasibility
      self.lmda5=torch.tensor(0.01).to(device) # pi l_inf
      # self.thres=torch.tensor(0.97).to(device)

      self.line_loc=line_loc.copy()
      self.binary_cell=my_gen_pred_binary()
    def calc(self,pred,label,x):
      mse_v=self.mse(pred[:,1,:],label[:,1,:])
      mse_p=self.mse(pred[:,0,:],label[:,0,:])
      # linf_v=(pred[:,1,:]-label[:,1,:]).norm(p=float('inf'))
      # linf_p=(pred[:,0,:]-label[:,0,:]).norm(p=float('inf'))

      # label_pred=pred[:,0,:] - self.vy_pd # price 
      # v_pred=pred[:,1,:]
      # label1=torch.squeeze(label_pred,1).transpose(0,1)
      # p_max=x[:,0,:].transpose(0,1)-x[:,1,:].transpose(0,1)
      # quadratic_b=x[:,4,:].transpose(0,1)
      # quadratic_a=x[:,5,:].transpose(0,1)
      # quadratic_center=(label1-quadratic_b)/(quadratic_a+1e-10)/2
      # p_inj=self.binary_cell(quadratic_center,p_max)
      # bus_inj=p_inj+x[:,1,:].transpose(0,1)
      # p_inj_r=torch.cat((bus_inj[:639,:],bus_inj[640:,:]))/100
      # # theta0=torch.matmul(self.r,p_inj_r) # dcpf model
      # # fdpf model start
      # # print(self.J1.shape,p_inj_dev.shape,self.t0.shape)
      # p_inj_dev=p_inj_r-self.p0
      # theta0=torch.matmul(self.J1,p_inj_dev) # fdpf model
      # # fdpf model end
      # ref_ang=torch.zeros(1,theta0.shape[1]).to(device)
      # theta=torch.cat([theta0[:639,:],ref_ang,theta0[639:,:]],0)+self.t0 # deviation +nominal
      # v_pred=v_pred.transpose(0,1)/self.vy_s+self.vy_d

      # # s penalty
      # theta1=theta[self.line_loc[:,0]-1,:]
      # theta2=theta[self.line_loc[:,1]-1,:]
      # V1=(v_pred[self.line_loc[:,0]-1,:]).double()
      # V2=(v_pred[self.line_loc[:,1]-1,:]).double()
      # f_p=(self.a*self.g*(V1*V1).T)-self.a*((V1*V2).T)*(self.g*torch.cos(theta1-theta2).T+self.b*torch.sin(theta1-theta2).T)
      # f_p=f_p.T
      # f_q=-self.a*(V1.T)*(self.a*V1.T)*(self.b+self.c/2)+self.a*((V1*V2).T)*(self.b*torch.cos(theta1-theta2).T-self.g*torch.sin(theta1-theta2).T)
      # f_q=f_q.T
      # s_pred=torch.sqrt(f_p*f_p+f_q*f_q)*100
      # s_penalty=torch.sigmoid(s_pred-self.s)+torch.sigmoid(-s_pred-self.s)
      # s_total=torch.sum(s_penalty)

      # # sji penalty
      # theta1=theta[self.line_loc[:,1]-1,:]
      # theta2=theta[self.line_loc[:,0]-1,:]
      # V1=(v_pred[self.line_loc[:,1]-1,:]).double()
      # V2=(v_pred[self.line_loc[:,0]-1,:]).double() 
      # fji_p=(self.a*self.g*(V1*V1).T)-self.a*((V1*V2).T)*(self.g*torch.cos(theta1-theta2).T+self.b*torch.sin(theta1-theta2).T)
      # fji_p=fji_p.T
      # fji_q=-self.a*(V1.T)*(self.a*V1.T)*(self.b+self.c/2)+self.a*((V1*V2).T)*(self.b*torch.cos(theta1-theta2).T-self.g*torch.sin(theta1-theta2).T)
      # fji_q=fji_q.T
      # sji_pred=torch.sqrt(fji_p*fji_p+fji_q*fji_q)*100
      # sji_penalty=torch.sigmoid(sji_pred-self.s)+torch.sigmoid(-sji_pred-self.s)
      # sji_total=torch.sum(sji_penalty)

      return self.lmda1*mse_v+self.lmda2*mse_p#+self.lmda3*linf_v+self.lmda5*linf_p+self.lmda4*s_total+self.lmda4*sji_total


my_loss=loss_func(f_max,G_line_tensor,B_line_tensor,B_shunt_tensor,Br_inv_tensor,a_tensor,line_loc,Jpf_tensor,theta0_tensor,pinj0_tensor,vy_scale_tensor,vy_deviation_tensor,pi_deviation_tensor)

# %%
optimizer=torch.optim.Adam(net.parameters())

# load the pretrained parameters
# path=root+'./data_1354ac_2022/ac_v_S_feasgnn_0318.pickle'
# path=root+'data_1354ac_2022/gnn_trained_ac1354.pickle' # unregularized
path=root+'data_1354ac_2022/feasgnn_trained_ac1354_04022022cold_unreg2.pickle' # unregularized
# try: net.load_state_dict(torch.load(path))
# except: pass
try: 
  net.load_state_dict(torch.load(path))
  print('params loaded')
except: 
  print('cold start')
  pass

## Training
t0=time.time()
max_epochs=2000
eval_epoch=5

# earlystopping
tolerance=5
min_delta=1e-3
previous=0

for epoch in range(max_epochs):
  # training loop
  train_loss=0.0
  for local_batch,local_label in training_generator:
    optimizer.zero_grad() # clear the past gradient
    logits=net(local_batch)
    loss=my_loss.calc(logits,local_label,local_batch)
    loss.backward()
    train_loss+=loss.item()
    optimizer.step() # update parameters of net
  loss_optm.append(train_loss/len(training_generator.dataset))
  print("Epoch %d | Training loss: %.4f"%(epoch,train_loss/len(training_generator.dataset)))
  # eval
  if (epoch+1)%eval_epoch==0:
    net.eval()
    eval_loss=0.0
    for local_batch,local_label in validation_generator:
      logits=net(local_batch)
      loss=my_loss.calc(logits,local_label,local_batch)
      eval_loss+=loss.item()
    eval_avg=eval_loss/len(validation_generator.dataset)
    if (epoch==0): previous=eval_avg
    else:
      if previous-eval_avg<min_delta: tolerance-=1
      if tolerance==0:
        # break
        pass
      previous=eval_avg
    print("Epoch %d | Eval loss: %.4f" % (epoch, eval_avg))
    loss_val.append([epoch, eval_loss/len(validation_generator.dataset)])
    net.train()
  # validation loop
  with torch.set_grad_enabled(False):
      pass
t1=time.time()
print("Training time:%.4fs"%(t1-t0))
# Out:
# params loaded
# Epoch 0 | Training loss: 299.9828
# Epoch 1 | Training loss: 299.7689
# Epoch 2 | Training loss: 299.5723
# Epoch 3 | Training loss: 299.4080
# Epoch 4 | Training loss: 299.1849
# Epoch 4 | Eval loss: 329.8334
# Epoch 5 | Training loss: 299.0566
# Epoch 6 | Training loss: 298.7864
# Epoch 7 | Training loss: 298.6349
# Epoch 8 | Training loss: 298.4663
# Epoch 9 | Training loss: 298.2418
# Epoch 9 | Eval loss: 329.2064
# Epoch 10 | Training loss: 298.0448
# Epoch 11 | Training loss: 297.8512
# Epoch 12 | Training loss: 297.7311
# Epoch 13 | Training loss: 297.4715
# Epoch 14 | Training loss: 297.3724
# Epoch 14 | Eval loss: 328.3195
# Epoch 15 | Training loss: 297.1022
# Epoch 16 | Training loss: 296.9616
# Epoch 17 | Training loss: 274.9772
# Epoch 18 | Training loss: 115.2727
# Epoch 19 | Training loss: 54.5299
# Epoch 19 | Eval loss: 41.2161
# Epoch 20 | Training loss: 28.3646
# Epoch 21 | Training loss: 16.6978
# Epoch 22 | Training loss: 10.9357
# Epoch 23 | Training loss: 7.5708
# Epoch 24 | Training loss: 5.6523
# Epoch 24 | Eval loss: 5.5606
# Epoch 25 | Training loss: 4.7906
# Epoch 26 | Training loss: 4.5009
# Epoch 27 | Training loss: 4.3560
# Epoch 28 | Training loss: 4.2859
# Epoch 29 | Training loss: 4.2558
# Epoch 29 | Eval loss: 4.6238
# Epoch 30 | Training loss: 4.2325
# Epoch 31 | Training loss: 4.2198
# Epoch 32 | Training loss: 4.2158
# Epoch 33 | Training loss: 4.2109
# Epoch 34 | Training loss: 4.1958
# Epoch 34 | Eval loss: 4.5807
# Epoch 35 | Training loss: 4.1944
# Epoch 36 | Training loss: 4.1990
# Epoch 37 | Training loss: 4.1993
# Epoch 38 | Training loss: 4.1809
# Epoch 39 | Training loss: 4.1806
# Epoch 39 | Eval loss: 4.5157
# Epoch 40 | Training loss: 4.2006
# Epoch 41 | Training loss: 4.1734
# Epoch 42 | Training loss: 4.1870
# Epoch 43 | Training loss: 4.1748
# Epoch 44 | Training loss: 4.1964
# Epoch 44 | Eval loss: 4.7550
# Epoch 45 | Training loss: 4.1943
# Epoch 46 | Training loss: 4.1841
# Epoch 47 | Training loss: 4.1748
# Epoch 48 | Training loss: 4.1867
# Epoch 49 | Training loss: 4.2041
# Epoch 49 | Eval loss: 4.4821
# Epoch 50 | Training loss: 4.1881
# Epoch 51 | Training loss: 4.1827
# Epoch 52 | Training loss: 4.1807
# Epoch 53 | Training loss: 4.1787
# Epoch 54 | Training loss: 4.1791
# Epoch 54 | Eval loss: 4.5406
# Epoch 55 | Training loss: 4.1692
# Epoch 56 | Training loss: 4.2056
# Epoch 57 | Training loss: 4.1751
# Epoch 58 | Training loss: 4.1660
# Epoch 59 | Training loss: 4.1803
# Epoch 59 | Eval loss: 4.6098
# Epoch 60 | Training loss: 4.1538
# Epoch 61 | Training loss: 4.1768
# Epoch 62 | Training loss: 4.1636
# Epoch 63 | Training loss: 4.1885
# Epoch 64 | Training loss: 4.1691
# Epoch 64 | Eval loss: 4.5683
# Epoch 65 | Training loss: 4.1748
# Epoch 66 | Training loss: 4.2061
# Epoch 67 | Training loss: 4.1634
# Epoch 68 | Training loss: 4.1715
# Epoch 69 | Training loss: 4.1867
# Epoch 69 | Eval loss: 4.4701
# Epoch 70 | Training loss: 4.1801
# Epoch 71 | Training loss: 4.1881
# Epoch 72 | Training loss: 4.1632
# Epoch 73 | Training loss: 4.1755
# Epoch 74 | Training loss: 4.1790
# Epoch 74 | Eval loss: 4.5488
# Epoch 75 | Training loss: 4.1891
# Epoch 76 | Training loss: 4.1803
# Epoch 77 | Training loss: 4.1640
# Epoch 78 | Training loss: 4.1655
# Epoch 79 | Training loss: 4.1792
# Epoch 79 | Eval loss: 4.5633
# Epoch 80 | Training loss: 4.1780
# Epoch 81 | Training loss: 4.1668
# Epoch 82 | Training loss: 4.1738
# Epoch 83 | Training loss: 4.1810
# Epoch 84 | Training loss: 4.1779
# Epoch 84 | Eval loss: 4.5368
# Epoch 85 | Training loss: 4.1819
# Epoch 86 | Training loss: 4.1871
# Epoch 87 | Training loss: 4.1773
# Epoch 88 | Training loss: 4.1686
# Epoch 89 | Training loss: 4.1648
# Epoch 89 | Eval loss: 4.4014
# Epoch 90 | Training loss: 4.1782
# Epoch 91 | Training loss: 4.1886
# Epoch 92 | Training loss: 4.1734
# Epoch 93 | Training loss: 4.2074
# Epoch 94 | Training loss: 4.1821
# Epoch 94 | Eval loss: 4.7127
# Epoch 95 | Training loss: 4.1707
# Epoch 96 | Training loss: 4.1835
# Epoch 97 | Training loss: 4.1616
# Epoch 98 | Training loss: 4.1660
# Epoch 99 | Training loss: 4.1677
# Epoch 99 | Eval loss: 4.4972
# Epoch 100 | Training loss: 4.1673
# Epoch 101 | Training loss: 4.1655
# Epoch 102 | Training loss: 4.1706
# Epoch 103 | Training loss: 4.1886
# Epoch 104 | Training loss: 4.1771
# Epoch 104 | Eval loss: 4.6534
# Epoch 105 | Training loss: 4.1784
# Epoch 106 | Training loss: 4.1790
# Epoch 107 | Training loss: 4.1629
# Epoch 108 | Training loss: 4.1761
# Epoch 109 | Training loss: 4.1724
# Epoch 109 | Eval loss: 4.5766
# Epoch 110 | Training loss: 4.1742
# Epoch 111 | Training loss: 4.1716
# Epoch 112 | Training loss: 4.1916
# Epoch 113 | Training loss: 4.1695
# Epoch 114 | Training loss: 4.1648
# Epoch 114 | Eval loss: 4.6178
# Epoch 115 | Training loss: 4.1780
# Epoch 116 | Training loss: 4.1710
# Epoch 117 | Training loss: 4.1944
# Epoch 118 | Training loss: 4.1668
# Epoch 119 | Training loss: 4.1532
# Epoch 119 | Eval loss: 4.3847
# Epoch 120 | Training loss: 4.1583
# Epoch 121 | Training loss: 4.1773
# Epoch 122 | Training loss: 4.1867
# Epoch 123 | Training loss: 4.1635
# Epoch 124 | Training loss: 4.1580
# Epoch 124 | Eval loss: 4.7413
# Epoch 125 | Training loss: 4.1643
# Epoch 126 | Training loss: 4.1717
# Epoch 127 | Training loss: 4.1843
# Epoch 128 | Training loss: 4.1853
# Epoch 129 | Training loss: 4.1702
# Epoch 129 | Eval loss: 4.5342
# Epoch 130 | Training loss: 4.1585
# Epoch 131 | Training loss: 4.1688
# Epoch 132 | Training loss: 4.1726
# Epoch 133 | Training loss: 4.1618
# Epoch 134 | Training loss: 4.1805
# Epoch 134 | Eval loss: 4.4939
# Epoch 135 | Training loss: 4.1932
# Epoch 136 | Training loss: 4.1868
# Epoch 137 | Training loss: 4.1545
# Epoch 138 | Training loss: 4.1677
# Epoch 139 | Training loss: 4.1759
# Epoch 139 | Eval loss: 4.4612
# Epoch 140 | Training loss: 4.1857
# Epoch 141 | Training loss: 4.1651
# Epoch 142 | Training loss: 4.1976
# Epoch 143 | Training loss: 4.1719
# Epoch 144 | Training loss: 4.1768
# Epoch 144 | Eval loss: 4.4341
# Epoch 145 | Training loss: 4.1805
# Epoch 146 | Training loss: 4.1670
# Epoch 147 | Training loss: 4.1599
# Epoch 148 | Training loss: 4.1733
# Epoch 149 | Training loss: 4.1715
# Epoch 149 | Eval loss: 4.4818
# Epoch 150 | Training loss: 4.1594
# Epoch 151 | Training loss: 4.1811
# Epoch 152 | Training loss: 4.1675
# Epoch 153 | Training loss: 4.1965
# Epoch 154 | Training loss: 4.1672
# Epoch 154 | Eval loss: 4.6293
# Epoch 155 | Training loss: 4.1762
# Epoch 156 | Training loss: 4.1696
# Epoch 157 | Training loss: 4.1773
# Epoch 158 | Training loss: 4.1667
# Epoch 159 | Training loss: 4.1678
# Epoch 159 | Eval loss: 4.4499
# Epoch 160 | Training loss: 4.1801
# Epoch 161 | Training loss: 4.1788
# Epoch 162 | Training loss: 4.1928
# Epoch 163 | Training loss: 4.1707
# Epoch 164 | Training loss: 4.1860
# Epoch 164 | Eval loss: 4.6363
# Epoch 165 | Training loss: 4.1793
# Epoch 166 | Training loss: 4.1989
# Epoch 167 | Training loss: 4.1601
# Epoch 168 | Training loss: 4.1711
# Epoch 169 | Training loss: 4.1594
# Epoch 169 | Eval loss: 4.4954
# Epoch 170 | Training loss: 4.1814
# Epoch 171 | Training loss: 4.1700
# Epoch 172 | Training loss: 4.1713
# Epoch 173 | Training loss: 4.1565
# Epoch 174 | Training loss: 4.1519
# Epoch 174 | Eval loss: 4.5486
# Epoch 175 | Training loss: 4.1785
# Epoch 176 | Training loss: 4.1673
# Epoch 177 | Training loss: 4.1598
# Epoch 178 | Training loss: 4.1865
# Epoch 179 | Training loss: 4.1898
# Epoch 179 | Eval loss: 4.5574
# Epoch 180 | Training loss: 4.2083
# Epoch 181 | Training loss: 4.2069
# Epoch 182 | Training loss: 4.1616
# Epoch 183 | Training loss: 4.1593
# Epoch 184 | Training loss: 4.1791
# Epoch 184 | Eval loss: 4.5191
# Epoch 185 | Training loss: 4.1664
# Epoch 186 | Training loss: 4.1827
# Epoch 187 | Training loss: 4.1569
# Epoch 188 | Training loss: 4.1820
# Epoch 189 | Training loss: 4.1709
# Epoch 189 | Eval loss: 4.6291
# Epoch 190 | Training loss: 4.1617
# Epoch 191 | Training loss: 4.1872
# Epoch 192 | Training loss: 4.1636
# Epoch 193 | Training loss: 4.2059
# Epoch 194 | Training loss: 4.1739
# Epoch 194 | Eval loss: 4.4373
# Epoch 195 | Training loss: 4.1749
# Epoch 196 | Training loss: 4.1701
# Epoch 197 | Training loss: 4.1782
# Epoch 198 | Training loss: 4.1840
# Epoch 199 | Training loss: 4.1836
# Epoch 199 | Eval loss: 4.4996
# Epoch 200 | Training loss: 4.1690
# Epoch 201 | Training loss: 4.1752
# Epoch 202 | Training loss: 4.1707
# Epoch 203 | Training loss: 4.1710
# Epoch 204 | Training loss: 4.1619
# Epoch 204 | Eval loss: 4.5583
# Epoch 205 | Training loss: 4.1630
# Epoch 206 | Training loss: 4.1808
# Epoch 207 | Training loss: 4.1819
# Epoch 208 | Training loss: 4.1753
# Epoch 209 | Training loss: 4.1814
# Epoch 209 | Eval loss: 4.5419
# Epoch 210 | Training loss: 4.1702
# Epoch 211 | Training loss: 4.1432
# Epoch 212 | Training loss: 4.1659
# Epoch 213 | Training loss: 4.1544
# Epoch 214 | Training loss: 4.1585
# Epoch 214 | Eval loss: 4.4116
# Epoch 215 | Training loss: 4.1692
# Epoch 216 | Training loss: 4.1844
# Epoch 217 | Training loss: 4.1898
# Epoch 218 | Training loss: 4.1725
# Epoch 219 | Training loss: 4.1683
# Epoch 219 | Eval loss: 4.5478
# Epoch 220 | Training loss: 4.1519
# Epoch 221 | Training loss: 4.1733
# Epoch 222 | Training loss: 4.1582
# Epoch 223 | Training loss: 4.1716
# Epoch 224 | Training loss: 4.1683
# Epoch 224 | Eval loss: 4.6683
# Epoch 225 | Training loss: 4.1859
# Epoch 226 | Training loss: 4.1875
# Epoch 227 | Training loss: 4.1764
# Epoch 228 | Training loss: 4.1545
# Epoch 229 | Training loss: 4.1718
# Epoch 229 | Eval loss: 4.5571
# Epoch 230 | Training loss: 4.1765
# Epoch 231 | Training loss: 4.1600
# Epoch 232 | Training loss: 4.1931
# Epoch 233 | Training loss: 4.1765
# Epoch 234 | Training loss: 4.1704
# Epoch 234 | Eval loss: 4.4898
# Epoch 235 | Training loss: 4.1903
# Epoch 236 | Training loss: 4.1809
# Epoch 237 | Training loss: 4.1947
# Epoch 238 | Training loss: 4.1924
# Epoch 239 | Training loss: 4.1703
# Epoch 239 | Eval loss: 4.5316
# Epoch 240 | Training loss: 4.1565
# Epoch 241 | Training loss: 4.1699
# Epoch 242 | Training loss: 4.1674
# Epoch 243 | Training loss: 4.1647
# Epoch 244 | Training loss: 4.1622
# Epoch 244 | Eval loss: 4.7214
# Epoch 245 | Training loss: 4.1521
# Epoch 246 | Training loss: 4.1680
# Epoch 247 | Training loss: 4.1610
# Epoch 248 | Training loss: 4.1634
# Epoch 249 | Training loss: 4.1531
# Epoch 249 | Eval loss: 4.4778
# Epoch 250 | Training loss: 4.1515
# Epoch 251 | Training loss: 4.1630
# Epoch 252 | Training loss: 4.1963
# Epoch 253 | Training loss: 4.1894
# Epoch 254 | Training loss: 4.1680
# Epoch 254 | Eval loss: 4.5265
# Epoch 255 | Training loss: 4.1767
# Epoch 256 | Training loss: 4.1633
# Epoch 257 | Training loss: 4.1854
# Epoch 258 | Training loss: 4.1727
# Epoch 259 | Training loss: 4.1737
# Epoch 259 | Eval loss: 4.5577
# Epoch 260 | Training loss: 4.1595
# Epoch 261 | Training loss: 4.1815
# Epoch 262 | Training loss: 4.1799
# Epoch 263 | Training loss: 4.1585
# Epoch 264 | Training loss: 4.2002
# Epoch 264 | Eval loss: 4.4516
# Epoch 265 | Training loss: 4.1680
# Epoch 266 | Training loss: 4.1743
# Epoch 267 | Training loss: 4.1622
# Epoch 268 | Training loss: 4.1541
# Epoch 269 | Training loss: 4.1753
# Epoch 269 | Eval loss: 4.5083
# Epoch 270 | Training loss: 4.1706
# Epoch 271 | Training loss: 4.1653
# Epoch 272 | Training loss: 4.1832
# Epoch 273 | Training loss: 4.1598
# Epoch 274 | Training loss: 4.1647
# Epoch 274 | Eval loss: 4.5360
# Epoch 275 | Training loss: 4.1621
# Epoch 276 | Training loss: 4.1648
# Epoch 277 | Training loss: 4.1703
# Epoch 278 | Training loss: 4.2037
# Epoch 279 | Training loss: 4.1819
# Epoch 279 | Eval loss: 4.4687
# Epoch 280 | Training loss: 4.1722
# Epoch 281 | Training loss: 4.1521
# Epoch 282 | Training loss: 4.1592
# Epoch 283 | Training loss: 4.1699
# Epoch 284 | Training loss: 4.1711
# Epoch 284 | Eval loss: 4.6293
# Epoch 285 | Training loss: 4.1417
# Epoch 286 | Training loss: 4.1644
# Epoch 287 | Training loss: 4.1661
# Epoch 288 | Training loss: 4.1624
# Epoch 289 | Training loss: 4.1717
# Epoch 289 | Eval loss: 4.5323
# Epoch 290 | Training loss: 4.1701
# Epoch 291 | Training loss: 4.1736
# Epoch 292 | Training loss: 4.1884
# Epoch 293 | Training loss: 4.1498
# Epoch 294 | Training loss: 4.1699
# Epoch 294 | Eval loss: 4.5812
# Epoch 295 | Training loss: 4.1728
# Epoch 296 | Training loss: 4.1802
# Epoch 297 | Training loss: 4.1593
# Epoch 298 | Training loss: 4.1880
# Epoch 299 | Training loss: 4.2016
# Epoch 299 | Eval loss: 4.6648
# Epoch 300 | Training loss: 4.1826
# Epoch 301 | Training loss: 4.1656
# Epoch 302 | Training loss: 4.1680
# Epoch 303 | Training loss: 4.1512
# Epoch 304 | Training loss: 4.1642
# Epoch 304 | Eval loss: 4.5597
# Epoch 305 | Training loss: 4.1633
# Epoch 306 | Training loss: 4.1621
# Epoch 307 | Training loss: 4.1488
# Epoch 308 | Training loss: 4.1751
# Epoch 309 | Training loss: 4.1677
# Epoch 309 | Eval loss: 4.4842
# Epoch 310 | Training loss: 4.1572
# Epoch 311 | Training loss: 4.1623
# Epoch 312 | Training loss: 4.1720
# Epoch 313 | Training loss: 4.1844
# Epoch 314 | Training loss: 4.1654
# Epoch 314 | Eval loss: 4.6372
# Epoch 315 | Training loss: 4.1686
# Epoch 316 | Training loss: 4.1711
# Epoch 317 | Training loss: 4.1797
# Epoch 318 | Training loss: 4.1689
# Epoch 319 | Training loss: 4.1693
# Epoch 319 | Eval loss: 4.7137
# Epoch 320 | Training loss: 4.1473
# Epoch 321 | Training loss: 4.1565
# Epoch 322 | Training loss: 4.1673
# Epoch 323 | Training loss: 4.1578
# Epoch 324 | Training loss: 4.1583
# Epoch 324 | Eval loss: 4.7413
# Epoch 325 | Training loss: 4.1461
# Epoch 326 | Training loss: 4.1533
# Epoch 327 | Training loss: 4.1658
# Epoch 328 | Training loss: 4.1767
# Epoch 329 | Training loss: 4.1618
# Epoch 329 | Eval loss: 4.6862
# Epoch 330 | Training loss: 4.1642
# Epoch 331 | Training loss: 4.1516
# Epoch 332 | Training loss: 4.1547
# Epoch 333 | Training loss: 4.1679
# Epoch 334 | Training loss: 4.1756
# Epoch 334 | Eval loss: 4.6265
# Epoch 335 | Training loss: 4.1613
# Epoch 336 | Training loss: 4.1681
# Epoch 337 | Training loss: 4.1659
# Epoch 338 | Training loss: 4.1594
# Epoch 339 | Training loss: 4.1713
# Epoch 339 | Eval loss: 4.5879
# Epoch 340 | Training loss: 4.1617
# Epoch 341 | Training loss: 4.1461
# Epoch 342 | Training loss: 4.1573
# Epoch 343 | Training loss: 4.1855
# Epoch 344 | Training loss: 4.1943
# Epoch 344 | Eval loss: 4.4109
# Epoch 345 | Training loss: 4.1382
# Epoch 346 | Training loss: 4.1769
# Epoch 347 | Training loss: 4.1780
# Epoch 348 | Training loss: 4.1677
# Epoch 349 | Training loss: 4.1575
# Epoch 349 | Eval loss: 4.4862
# Epoch 350 | Training loss: 4.1838
# Epoch 351 | Training loss: 4.1666
# Epoch 352 | Training loss: 4.1649
# Epoch 353 | Training loss: 4.1695
# Epoch 354 | Training loss: 4.1659
# Epoch 354 | Eval loss: 4.5593
# Epoch 355 | Training loss: 4.1767
# Epoch 356 | Training loss: 4.1729
# Epoch 357 | Training loss: 4.1722
# Epoch 358 | Training loss: 4.2169
# Epoch 359 | Training loss: 4.1513
# Epoch 359 | Eval loss: 4.5774
# Epoch 360 | Training loss: 4.1569
# Epoch 361 | Training loss: 4.1546
# Epoch 362 | Training loss: 4.1578
# Epoch 363 | Training loss: 4.1441
# Epoch 364 | Training loss: 4.1621
# Epoch 364 | Eval loss: 4.4971
# Epoch 365 | Training loss: 4.1642
# Epoch 366 | Training loss: 4.1594
# Epoch 367 | Training loss: 4.1521
# Epoch 368 | Training loss: 4.1528
# Epoch 369 | Training loss: 4.1466
# Epoch 369 | Eval loss: 4.8275
# Epoch 370 | Training loss: 4.1729
# Epoch 371 | Training loss: 4.1667
# Epoch 372 | Training loss: 4.1769
# Epoch 373 | Training loss: 4.1617
# Epoch 374 | Training loss: 4.1658
# Epoch 374 | Eval loss: 4.6950
# Epoch 375 | Training loss: 4.1623
# Epoch 376 | Training loss: 4.1609
# Epoch 377 | Training loss: 4.1602
# Epoch 378 | Training loss: 4.1596
# Epoch 379 | Training loss: 4.1602
# Epoch 379 | Eval loss: 4.5204
# Epoch 380 | Training loss: 4.1517
# Epoch 381 | Training loss: 4.1595
# Epoch 382 | Training loss: 4.1468
# Epoch 383 | Training loss: 4.1681
# Epoch 384 | Training loss: 4.1534
# Epoch 384 | Eval loss: 4.4828
# Epoch 385 | Training loss: 4.1690
# Epoch 386 | Training loss: 4.1512
# Epoch 387 | Training loss: 4.1555
# Epoch 388 | Training loss: 4.1529
# Epoch 389 | Training loss: 4.1635
# Epoch 389 | Eval loss: 4.5122
# Epoch 390 | Training loss: 4.1704
# Epoch 391 | Training loss: 4.1571
# Epoch 392 | Training loss: 4.1525
# Epoch 393 | Training loss: 4.1483
# Epoch 394 | Training loss: 4.1478
# Epoch 394 | Eval loss: 4.5987
# Epoch 395 | Training loss: 4.1430
# Epoch 396 | Training loss: 4.1475
# Epoch 397 | Training loss: 4.1768
# Epoch 398 | Training loss: 4.1805
# Epoch 399 | Training loss: 4.1623
# Epoch 399 | Eval loss: 4.5469
# Epoch 400 | Training loss: 4.1619
# Epoch 401 | Training loss: 4.1514
# Epoch 402 | Training loss: 4.1773
# Epoch 403 | Training loss: 4.1538
# Epoch 404 | Training loss: 4.1339
# Epoch 404 | Eval loss: 4.5249
# Epoch 405 | Training loss: 4.1636
# Epoch 406 | Training loss: 4.1696
# Epoch 407 | Training loss: 4.1555
# Epoch 408 | Training loss: 4.1720
# Epoch 409 | Training loss: 4.1490
# Epoch 409 | Eval loss: 4.4714
# Epoch 410 | Training loss: 4.1609
# Epoch 411 | Training loss: 4.1539
# Epoch 412 | Training loss: 4.1554
# Epoch 413 | Training loss: 4.1395
# Epoch 414 | Training loss: 4.1804
# Epoch 414 | Eval loss: 4.5936
# Epoch 415 | Training loss: 4.1600
# Epoch 416 | Training loss: 4.1602
# Epoch 417 | Training loss: 4.1586
# Epoch 418 | Training loss: 4.1901
# Epoch 419 | Training loss: 4.1835
# Epoch 419 | Eval loss: 4.6081
# Epoch 420 | Training loss: 4.1652
# Epoch 421 | Training loss: 4.1509
# Epoch 422 | Training loss: 4.1478
# Epoch 423 | Training loss: 4.1556
# Epoch 424 | Training loss: 4.1787
# Epoch 424 | Eval loss: 4.5619
# Epoch 425 | Training loss: 4.1606
# Epoch 426 | Training loss: 4.1556
# Epoch 427 | Training loss: 4.1662
# Epoch 428 | Training loss: 4.1650
# Epoch 429 | Training loss: 4.1470
# Epoch 429 | Eval loss: 4.6815
# Epoch 430 | Training loss: 4.1475
# Epoch 431 | Training loss: 4.1646
# Epoch 432 | Training loss: 4.1491
# Epoch 433 | Training loss: 4.1498
# Epoch 434 | Training loss: 4.1520
# Epoch 434 | Eval loss: 4.4638
# Epoch 435 | Training loss: 4.1596
# Epoch 436 | Training loss: 4.1523
# Epoch 437 | Training loss: 4.1453
# Epoch 438 | Training loss: 4.1616
# Epoch 439 | Training loss: 4.1395
# Epoch 439 | Eval loss: 4.5363
# Epoch 440 | Training loss: 4.1675
# Epoch 441 | Training loss: 4.1354
# Epoch 442 | Training loss: 4.1396
# Epoch 443 | Training loss: 4.1481
# Epoch 444 | Training loss: 4.1680
# Epoch 444 | Eval loss: 4.5239
# Epoch 445 | Training loss: 4.1550
# Epoch 446 | Training loss: 4.1774
# Epoch 447 | Training loss: 4.1391
# Epoch 448 | Training loss: 4.1373
# Epoch 449 | Training loss: 4.1572
# Epoch 449 | Eval loss: 4.5876
# Epoch 450 | Training loss: 4.1788
# Epoch 451 | Training loss: 4.1407
# Epoch 452 | Training loss: 4.1568
# Epoch 453 | Training loss: 4.1405
# Epoch 454 | Training loss: 4.1451
# Epoch 454 | Eval loss: 4.6663
# Epoch 455 | Training loss: 4.1473
# Epoch 456 | Training loss: 4.1610
# Epoch 457 | Training loss: 4.1582
# Epoch 458 | Training loss: 4.1479
# Epoch 459 | Training loss: 4.1509
# Epoch 459 | Eval loss: 4.5152
# Epoch 460 | Training loss: 4.1830
# Epoch 461 | Training loss: 4.1516
# Epoch 462 | Training loss: 4.1406
# Epoch 463 | Training loss: 4.1722
# Epoch 464 | Training loss: 4.1422
# Epoch 464 | Eval loss: 4.3945
# Epoch 465 | Training loss: 4.2054
# Epoch 466 | Training loss: 4.1611
# Epoch 467 | Training loss: 4.1494
# Epoch 468 | Training loss: 4.1418
# Epoch 469 | Training loss: 4.1686
# Epoch 469 | Eval loss: 4.6078
# Epoch 470 | Training loss: 4.1388
# Epoch 471 | Training loss: 4.1450
# Epoch 472 | Training loss: 4.1570
# Epoch 473 | Training loss: 4.1515
# Epoch 474 | Training loss: 4.1499
# Epoch 474 | Eval loss: 4.5833
# Epoch 475 | Training loss: 4.1478
# Epoch 476 | Training loss: 4.1621
# Epoch 477 | Training loss: 4.1787
# Epoch 478 | Training loss: 4.1602
# Epoch 479 | Training loss: 4.1630
# Epoch 479 | Eval loss: 4.6654
# Epoch 480 | Training loss: 4.1547
# Epoch 481 | Training loss: 4.1702
# Epoch 482 | Training loss: 4.1406
# Epoch 483 | Training loss: 4.1619
# Epoch 484 | Training loss: 4.1596
# Epoch 484 | Eval loss: 4.5364
# Epoch 485 | Training loss: 4.1417
# Epoch 486 | Training loss: 4.1597
# Epoch 487 | Training loss: 4.1868
# Epoch 488 | Training loss: 4.1403
# Epoch 489 | Training loss: 4.1465
# Epoch 489 | Eval loss: 4.5144
# Epoch 490 | Training loss: 4.1452
# Epoch 491 | Training loss: 4.1451
# Epoch 492 | Training loss: 4.1457
# Epoch 493 | Training loss: 4.1461
# Epoch 494 | Training loss: 4.1433
# Epoch 494 | Eval loss: 4.5444
# Epoch 495 | Training loss: 4.1498
# Epoch 496 | Training loss: 4.1552
# Epoch 497 | Training loss: 4.1672
# Epoch 498 | Training loss: 4.1986
# Epoch 499 | Training loss: 4.1597
# Epoch 499 | Eval loss: 4.7176
# Epoch 500 | Training loss: 4.1335
# Epoch 501 | Training loss: 4.1293
# Epoch 502 | Training loss: 4.1432
# Epoch 503 | Training loss: 4.1529
# Epoch 504 | Training loss: 4.1536
# Epoch 504 | Eval loss: 4.6075
# Epoch 505 | Training loss: 4.1474
# Epoch 506 | Training loss: 4.1552
# Epoch 507 | Training loss: 4.1517
# Epoch 508 | Training loss: 4.1489
# Epoch 509 | Training loss: 4.1461
# Epoch 509 | Eval loss: 4.5546
# Epoch 510 | Training loss: 4.1545
# Epoch 511 | Training loss: 4.1645
# Epoch 512 | Training loss: 4.1508
# Epoch 513 | Training loss: 4.1680
# Epoch 514 | Training loss: 4.1449
# Epoch 514 | Eval loss: 4.4935
# Epoch 515 | Training loss: 4.1615
# Epoch 516 | Training loss: 4.1589
# Epoch 517 | Training loss: 4.1486
# Epoch 518 | Training loss: 4.1486
# Epoch 519 | Training loss: 4.1857
# Epoch 519 | Eval loss: 4.6894
# Epoch 520 | Training loss: 4.1466
# Epoch 521 | Training loss: 4.1550
# Epoch 522 | Training loss: 4.1370
# Epoch 523 | Training loss: 4.1512
# Epoch 524 | Training loss: 4.1236
# Epoch 524 | Eval loss: 4.5170
# Epoch 525 | Training loss: 4.1546
# Epoch 526 | Training loss: 4.1521
# Epoch 527 | Training loss: 4.1590
# Epoch 528 | Training loss: 4.1636
# Epoch 529 | Training loss: 4.1749
# Epoch 529 | Eval loss: 4.5601
# Epoch 530 | Training loss: 4.1501
# Epoch 531 | Training loss: 4.1427
# Epoch 532 | Training loss: 4.1821
# Epoch 533 | Training loss: 4.1541
# Epoch 534 | Training loss: 4.1361
# Epoch 534 | Eval loss: 4.5489
# Epoch 535 | Training loss: 4.1684
# Epoch 536 | Training loss: 4.1443
# Epoch 537 | Training loss: 4.1503
# Epoch 538 | Training loss: 4.1414
# Epoch 539 | Training loss: 4.1499
# Epoch 539 | Eval loss: 4.5302
# Epoch 540 | Training loss: 4.1674
# Epoch 541 | Training loss: 4.1336
# Epoch 542 | Training loss: 4.1454
# Epoch 543 | Training loss: 4.1352
# Epoch 544 | Training loss: 4.1435
# Epoch 544 | Eval loss: 4.4895
# Epoch 545 | Training loss: 4.1679
# Epoch 546 | Training loss: 4.1727
# Epoch 547 | Training loss: 4.1575
# Epoch 548 | Training loss: 4.1459
# Epoch 549 | Training loss: 4.1558
# Epoch 549 | Eval loss: 4.4250
# Epoch 550 | Training loss: 4.1429
# Epoch 551 | Training loss: 4.1652
# Epoch 552 | Training loss: 4.1423
# Epoch 553 | Training loss: 4.1391
# Epoch 554 | Training loss: 4.1483
# Epoch 554 | Eval loss: 4.6660
# Epoch 555 | Training loss: 4.1535
# Epoch 556 | Training loss: 4.1410
# Epoch 557 | Training loss: 4.1735
# Epoch 558 | Training loss: 4.1634
# Epoch 559 | Training loss: 4.1368
# Epoch 559 | Eval loss: 4.5260
# Epoch 560 | Training loss: 4.1455
# Epoch 561 | Training loss: 4.1550
# Epoch 562 | Training loss: 4.1350
# Epoch 563 | Training loss: 4.1660
# Epoch 564 | Training loss: 4.1485
# Epoch 564 | Eval loss: 4.5237
# Epoch 565 | Training loss: 4.1632
# Epoch 566 | Training loss: 4.1775
# Epoch 567 | Training loss: 4.1602
# Epoch 568 | Training loss: 4.1676
# Epoch 569 | Training loss: 4.1483
# Epoch 569 | Eval loss: 4.6176
# Epoch 570 | Training loss: 4.1662
# Epoch 571 | Training loss: 4.1581
# Epoch 572 | Training loss: 4.1399
# Epoch 573 | Training loss: 4.1492
# Epoch 574 | Training loss: 4.1530
# Epoch 574 | Eval loss: 4.5146
# Epoch 575 | Training loss: 4.1691
# Epoch 576 | Training loss: 4.1297
# Epoch 577 | Training loss: 4.1494
# Epoch 578 | Training loss: 4.1679
# Epoch 579 | Training loss: 4.1781
# Epoch 579 | Eval loss: 4.8214
# Epoch 580 | Training loss: 4.1598
# Epoch 581 | Training loss: 4.1694
# Epoch 582 | Training loss: 4.1614
# Epoch 583 | Training loss: 4.1599
# Epoch 584 | Training loss: 4.1731
# Epoch 584 | Eval loss: 4.6579
# Epoch 585 | Training loss: 4.1705
# Epoch 586 | Training loss: 4.1573
# Epoch 587 | Training loss: 4.1567
# Epoch 588 | Training loss: 4.1736
# Epoch 589 | Training loss: 4.1642
# Epoch 589 | Eval loss: 4.5893
# Epoch 590 | Training loss: 4.1743
# Epoch 591 | Training loss: 4.1643
# Epoch 592 | Training loss: 4.1483
# Epoch 593 | Training loss: 4.1659
# Epoch 594 | Training loss: 4.1386
# Epoch 594 | Eval loss: 4.5848
# Epoch 595 | Training loss: 4.2073
# Epoch 596 | Training loss: 4.1476
# Epoch 597 | Training loss: 4.1512
# Epoch 598 | Training loss: 4.1404
# Epoch 599 | Training loss: 4.1503
# Epoch 599 | Eval loss: 4.5548
# Epoch 600 | Training loss: 4.1580
# Epoch 601 | Training loss: 4.1815
# Epoch 602 | Training loss: 4.1519
# Epoch 603 | Training loss: 4.1293
# Epoch 604 | Training loss: 4.1606
# Epoch 604 | Eval loss: 4.4048
# Epoch 605 | Training loss: 4.1426
# Epoch 606 | Training loss: 4.1517
# Epoch 607 | Training loss: 4.1516
# Epoch 608 | Training loss: 4.1420
# Epoch 609 | Training loss: 4.1652
# Epoch 609 | Eval loss: 4.6815
# Epoch 610 | Training loss: 4.1559
# Epoch 611 | Training loss: 4.1386
# Epoch 612 | Training loss: 4.1583
# Epoch 613 | Training loss: 4.1584
# Epoch 614 | Training loss: 4.1440
# Epoch 614 | Eval loss: 4.4182
# Epoch 615 | Training loss: 4.1572
# Epoch 616 | Training loss: 4.1504
# Epoch 617 | Training loss: 4.1589
# Epoch 618 | Training loss: 4.1383
# Epoch 619 | Training loss: 4.1472
# Epoch 619 | Eval loss: 4.6479
# Epoch 620 | Training loss: 4.1606
# Epoch 621 | Training loss: 4.1837
# Epoch 622 | Training loss: 4.1374
# Epoch 623 | Training loss: 4.1294
# Epoch 624 | Training loss: 4.1505
# Epoch 624 | Eval loss: 4.5456
# Epoch 625 | Training loss: 4.1575
# Epoch 626 | Training loss: 4.1503
# Epoch 627 | Training loss: 4.1329
# Epoch 628 | Training loss: 4.1538
# Epoch 629 | Training loss: 4.1522
# Epoch 629 | Eval loss: 4.5294
# Epoch 630 | Training loss: 4.1683
# Epoch 631 | Training loss: 4.1464
# Epoch 632 | Training loss: 4.1661
# Epoch 633 | Training loss: 4.1522
# Epoch 634 | Training loss: 4.1357
# Epoch 634 | Eval loss: 4.5083
# Epoch 635 | Training loss: 4.1446
# Epoch 636 | Training loss: 4.1348
# Epoch 637 | Training loss: 4.1539
# Epoch 638 | Training loss: 4.1390
# Epoch 639 | Training loss: 4.1485
# Epoch 639 | Eval loss: 4.5300
# Epoch 640 | Training loss: 4.1491
# Epoch 641 | Training loss: 4.1701
# Epoch 642 | Training loss: 4.1374
# Epoch 643 | Training loss: 4.1490
# Epoch 644 | Training loss: 4.1471
# Epoch 644 | Eval loss: 4.5645
# Epoch 645 | Training loss: 4.1498
# Epoch 646 | Training loss: 4.1871
# Epoch 647 | Training loss: 4.1543
# Epoch 648 | Training loss: 4.1457
# Epoch 649 | Training loss: 4.1448
# Epoch 649 | Eval loss: 4.4723
# Epoch 650 | Training loss: 4.1663
# Epoch 651 | Training loss: 4.1430
# Epoch 652 | Training loss: 4.1350
# Epoch 653 | Training loss: 4.1420
# Epoch 654 | Training loss: 4.1432
# Epoch 654 | Eval loss: 4.5004
# Epoch 655 | Training loss: 4.1448
# Epoch 656 | Training loss: 4.1473
# Epoch 657 | Training loss: 4.1596
# Epoch 658 | Training loss: 4.1487
# Epoch 659 | Training loss: 4.1583
# Epoch 659 | Eval loss: 4.6084
# Epoch 660 | Training loss: 4.1423
# Epoch 661 | Training loss: 4.1356
# Epoch 662 | Training loss: 4.1528
# Epoch 663 | Training loss: 4.1485
# Epoch 664 | Training loss: 4.1397
# Epoch 664 | Eval loss: 4.6037
# Epoch 665 | Training loss: 4.1406
# Epoch 666 | Training loss: 4.1365
# Epoch 667 | Training loss: 4.1297
# Epoch 668 | Training loss: 4.1532
# Epoch 669 | Training loss: 4.1461
# Epoch 669 | Eval loss: 4.6164
# Epoch 670 | Training loss: 4.1254
# Epoch 671 | Training loss: 4.1417
# Epoch 672 | Training loss: 4.1661
# Epoch 673 | Training loss: 4.1558
# Epoch 674 | Training loss: 4.1511
# Epoch 674 | Eval loss: 4.6851
# Epoch 675 | Training loss: 4.1410
# Epoch 676 | Training loss: 4.1485
# Epoch 677 | Training loss: 4.1444
# Epoch 678 | Training loss: 4.1329
# Epoch 679 | Training loss: 4.1643
# Epoch 679 | Eval loss: 4.7117
# Epoch 680 | Training loss: 4.1450
# Epoch 681 | Training loss: 4.1468
# Epoch 682 | Training loss: 4.1431
# Epoch 683 | Training loss: 4.1593
# Epoch 684 | Training loss: 4.1464
# Epoch 684 | Eval loss: 4.6070
# Epoch 685 | Training loss: 4.1562
# Epoch 686 | Training loss: 4.1582
# Epoch 687 | Training loss: 4.1346
# Epoch 688 | Training loss: 4.1503
# Epoch 689 | Training loss: 4.1536
# Epoch 689 | Eval loss: 4.8072
# Epoch 690 | Training loss: 4.1425
# Epoch 691 | Training loss: 4.1522
# Epoch 692 | Training loss: 4.1403
# Epoch 693 | Training loss: 4.1480
# Epoch 694 | Training loss: 4.1688
# Epoch 694 | Eval loss: 4.5211
# Epoch 695 | Training loss: 4.1523
# Epoch 696 | Training loss: 4.1709
# Epoch 697 | Training loss: 4.1558
# Epoch 698 | Training loss: 4.1398
# Epoch 699 | Training loss: 4.1332
# Epoch 699 | Eval loss: 4.6504
# Epoch 700 | Training loss: 4.1374
# Epoch 701 | Training loss: 4.1666
# Epoch 702 | Training loss: 4.1550
# Epoch 703 | Training loss: 4.1441
# Epoch 704 | Training loss: 4.1513
# Epoch 704 | Eval loss: 4.6070
# Epoch 705 | Training loss: 4.1577
# Epoch 706 | Training loss: 4.1530
# Epoch 707 | Training loss: 4.1300
# Epoch 708 | Training loss: 4.1575
# Epoch 709 | Training loss: 4.1322
# Epoch 709 | Eval loss: 4.5593
# Epoch 710 | Training loss: 4.1519
# Epoch 711 | Training loss: 4.1478
# Epoch 712 | Training loss: 4.1400
# Epoch 713 | Training loss: 4.1727
# Epoch 714 | Training loss: 4.1403
# Epoch 714 | Eval loss: 4.7213
# Epoch 715 | Training loss: 4.1695
# Epoch 716 | Training loss: 4.1449
# Epoch 717 | Training loss: 4.1337
# Epoch 718 | Training loss: 4.1594
# Epoch 719 | Training loss: 4.1732
# Epoch 719 | Eval loss: 4.6109
# Epoch 720 | Training loss: 4.1723
# Epoch 721 | Training loss: 4.1408
# Epoch 722 | Training loss: 4.1364
# Epoch 723 | Training loss: 4.1550
# Epoch 724 | Training loss: 4.1701
# Epoch 724 | Eval loss: 4.4942
# Epoch 725 | Training loss: 4.1356
# Epoch 726 | Training loss: 4.1734
# Epoch 727 | Training loss: 4.1505
# Epoch 728 | Training loss: 4.1481
# Epoch 729 | Training loss: 4.1526
# Epoch 729 | Eval loss: 4.4832
# Epoch 730 | Training loss: 4.1604
# Epoch 731 | Training loss: 4.1399
# Epoch 732 | Training loss: 4.1397
# Epoch 733 | Training loss: 4.1553
# Epoch 734 | Training loss: 4.1428
# Epoch 734 | Eval loss: 4.4679
# Epoch 735 | Training loss: 4.1571
# Epoch 736 | Training loss: 4.1663
# Epoch 737 | Training loss: 4.1393
# Epoch 738 | Training loss: 4.1402
# Epoch 739 | Training loss: 4.1455
# Epoch 739 | Eval loss: 4.5732
# Epoch 740 | Training loss: 4.1442
# Epoch 741 | Training loss: 4.1410
# Epoch 742 | Training loss: 4.1437
# Epoch 743 | Training loss: 4.1397
# Epoch 744 | Training loss: 4.1356
# Epoch 744 | Eval loss: 4.5211
# Epoch 745 | Training loss: 4.1389
# Epoch 746 | Training loss: 4.1603
# Epoch 747 | Training loss: 4.1386
# Epoch 748 | Training loss: 4.1545
# Epoch 749 | Training loss: 4.1545
# Epoch 749 | Eval loss: 4.4814
# Epoch 750 | Training loss: 4.1568
# Epoch 751 | Training loss: 4.1394
# Epoch 752 | Training loss: 4.1303
# Epoch 753 | Training loss: 4.1456
# Epoch 754 | Training loss: 4.1542
# Epoch 754 | Eval loss: 4.5140
# Epoch 755 | Training loss: 4.1489
# Epoch 756 | Training loss: 4.1641
# Epoch 757 | Training loss: 4.1764
# Epoch 758 | Training loss: 4.1429
# Epoch 759 | Training loss: 4.1531
# Epoch 759 | Eval loss: 4.5747
# Epoch 760 | Training loss: 4.1771
# Epoch 761 | Training loss: 4.1614
# Epoch 762 | Training loss: 4.1417
# Epoch 763 | Training loss: 4.1528
# Epoch 764 | Training loss: 4.1710
# Epoch 764 | Eval loss: 4.6593
# Epoch 765 | Training loss: 4.1372
# Epoch 766 | Training loss: 4.1389
# Epoch 767 | Training loss: 4.1706
# Epoch 768 | Training loss: 4.1627
# Epoch 769 | Training loss: 4.1408
# Epoch 769 | Eval loss: 4.6642
# Epoch 770 | Training loss: 4.1657
# Epoch 771 | Training loss: 4.1367
# Epoch 772 | Training loss: 4.1386
# Epoch 773 | Training loss: 4.1529
# Epoch 774 | Training loss: 4.1351
# Epoch 774 | Eval loss: 4.5145
# Epoch 775 | Training loss: 4.1239
# Epoch 776 | Training loss: 4.1585
# Epoch 777 | Training loss: 4.1637
# Epoch 778 | Training loss: 4.1498
# Epoch 779 | Training loss: 4.1748
# Epoch 779 | Eval loss: 4.6635
# Epoch 780 | Training loss: 4.1457
# Epoch 781 | Training loss: 4.1351
# Epoch 782 | Training loss: 4.1548
# Epoch 783 | Training loss: 4.1508
# Epoch 784 | Training loss: 4.1555
# Epoch 784 | Eval loss: 4.6261
# Epoch 785 | Training loss: 4.1262
# Epoch 786 | Training loss: 4.1654
# Epoch 787 | Training loss: 4.1680
# Epoch 788 | Training loss: 4.1735
# Epoch 789 | Training loss: 4.1508
# Epoch 789 | Eval loss: 4.6058
# Epoch 790 | Training loss: 4.1466
# Epoch 791 | Training loss: 4.1550
# Epoch 792 | Training loss: 4.1414
# Epoch 793 | Training loss: 4.1792
# Epoch 794 | Training loss: 4.1467
# Epoch 794 | Eval loss: 4.4795
# Epoch 795 | Training loss: 4.1380
# Epoch 796 | Training loss: 4.1308
# Epoch 797 | Training loss: 4.1339
# Epoch 798 | Training loss: 4.1570
# Epoch 799 | Training loss: 4.1399
# Epoch 799 | Eval loss: 4.4994
# Epoch 800 | Training loss: 4.1397
# Epoch 801 | Training loss: 4.1431
# Epoch 802 | Training loss: 4.1661
# Epoch 803 | Training loss: 4.1622
# Epoch 804 | Training loss: 4.1457
# Epoch 804 | Eval loss: 4.5851
# Epoch 805 | Training loss: 4.1623
# Epoch 806 | Training loss: 4.1529
# Epoch 807 | Training loss: 4.1323
# Epoch 808 | Training loss: 4.1391
# Epoch 809 | Training loss: 4.1387
# Epoch 809 | Eval loss: 4.6983
# Epoch 810 | Training loss: 4.1432
# Epoch 811 | Training loss: 4.1478
# Epoch 812 | Training loss: 4.1402
# Epoch 813 | Training loss: 4.1611
# Epoch 814 | Training loss: 4.1591
# Epoch 814 | Eval loss: 4.6595
# Epoch 815 | Training loss: 4.1402
# Epoch 816 | Training loss: 4.1595
# Epoch 817 | Training loss: 4.1578
# Epoch 818 | Training loss: 4.1454
# Epoch 819 | Training loss: 4.1664
# Epoch 819 | Eval loss: 4.6913
# Epoch 820 | Training loss: 4.1489
# Epoch 821 | Training loss: 4.1249
# Epoch 822 | Training loss: 4.1677
# Epoch 823 | Training loss: 4.1433
# Epoch 824 | Training loss: 4.1595
# Epoch 824 | Eval loss: 4.5495
# Epoch 825 | Training loss: 4.1373
# Epoch 826 | Training loss: 4.1489
# Epoch 827 | Training loss: 4.1537
# Epoch 828 | Training loss: 4.1520
# Epoch 829 | Training loss: 4.1490
# Epoch 829 | Eval loss: 4.7487
# Epoch 830 | Training loss: 4.1361
# Epoch 831 | Training loss: 4.1602
# Epoch 832 | Training loss: 4.1515
# Epoch 833 | Training loss: 4.1659
# Epoch 834 | Training loss: 4.1560
# Epoch 834 | Eval loss: 4.4727
# Epoch 835 | Training loss: 4.1324
# Epoch 836 | Training loss: 4.1567
# Epoch 837 | Training loss: 4.1632
# Epoch 838 | Training loss: 4.1682
# Epoch 839 | Training loss: 4.1405
# Epoch 839 | Eval loss: 4.5788
# Epoch 840 | Training loss: 4.1443
# Epoch 841 | Training loss: 4.1322
# Epoch 842 | Training loss: 4.1508
# Epoch 843 | Training loss: 4.1523
# Epoch 844 | Training loss: 4.1451
# Epoch 844 | Eval loss: 4.5294
# Epoch 845 | Training loss: 4.1394
# Epoch 846 | Training loss: 4.1382
# Epoch 847 | Training loss: 4.1448
# Epoch 848 | Training loss: 4.1468
# Epoch 849 | Training loss: 4.1525
# Epoch 849 | Eval loss: 4.6110
# Epoch 850 | Training loss: 4.1542
# Epoch 851 | Training loss: 4.1524
# Epoch 852 | Training loss: 4.1477
# Epoch 853 | Training loss: 4.1459
# Epoch 854 | Training loss: 4.1569
# Epoch 854 | Eval loss: 4.8159
# Epoch 855 | Training loss: 4.1479
# Epoch 856 | Training loss: 4.1455
# Epoch 857 | Training loss: 4.1467
# Epoch 858 | Training loss: 4.1437
# Epoch 859 | Training loss: 4.1253
# Epoch 859 | Eval loss: 4.5526
# Epoch 860 | Training loss: 4.1314
# Epoch 861 | Training loss: 4.1583
# Epoch 862 | Training loss: 4.1701
# Epoch 863 | Training loss: 4.1273
# Epoch 864 | Training loss: 4.1473
# Epoch 864 | Eval loss: 4.5362
# Epoch 865 | Training loss: 4.1399
# Epoch 866 | Training loss: 4.1377
# Epoch 867 | Training loss: 4.1453
# Epoch 868 | Training loss: 4.1642
# Epoch 869 | Training loss: 4.1489
# Epoch 869 | Eval loss: 4.4799
# Epoch 870 | Training loss: 4.1415
# Epoch 871 | Training loss: 4.1454
# Epoch 872 | Training loss: 4.1526
# Epoch 873 | Training loss: 4.1278
# Epoch 874 | Training loss: 4.1302
# Epoch 874 | Eval loss: 4.7139
# Epoch 875 | Training loss: 4.1449
# Epoch 876 | Training loss: 4.1281
# Epoch 877 | Training loss: 4.1649
# Epoch 878 | Training loss: 4.1458
# Epoch 879 | Training loss: 4.1367
# Epoch 879 | Eval loss: 4.6415
# Epoch 880 | Training loss: 4.1521
# Epoch 881 | Training loss: 4.1311
# Epoch 882 | Training loss: 4.1928
# Epoch 883 | Training loss: 4.1482
# Epoch 884 | Training loss: 4.1329
# Epoch 884 | Eval loss: 4.5340
# Epoch 885 | Training loss: 4.1449
# Epoch 886 | Training loss: 4.1498
# Epoch 887 | Training loss: 4.1537
# Epoch 888 | Training loss: 4.1694
# Epoch 889 | Training loss: 4.1438
# Epoch 889 | Eval loss: 4.6445
# Epoch 890 | Training loss: 4.1504
# Epoch 891 | Training loss: 4.1416
# Epoch 892 | Training loss: 4.1706
# Epoch 893 | Training loss: 4.1684
# Epoch 894 | Training loss: 4.1244
# Epoch 894 | Eval loss: 4.5157
# Epoch 895 | Training loss: 4.1614
# Epoch 896 | Training loss: 4.1329
# Epoch 897 | Training loss: 4.1341
# Epoch 898 | Training loss: 4.1597
# Epoch 899 | Training loss: 4.1699
# Epoch 899 | Eval loss: 4.5375
# Epoch 900 | Training loss: 4.1583
# Epoch 901 | Training loss: 4.1348
# Epoch 902 | Training loss: 4.1650
# Epoch 903 | Training loss: 4.1633
# Epoch 904 | Training loss: 4.1637
# Epoch 904 | Eval loss: 4.5476
# Epoch 905 | Training loss: 4.1685
# Epoch 906 | Training loss: 4.1477
# Epoch 907 | Training loss: 4.1298
# Epoch 908 | Training loss: 4.1709
# Epoch 909 | Training loss: 4.1468
# Epoch 909 | Eval loss: 4.7282
# Epoch 910 | Training loss: 4.1382
# Epoch 911 | Training loss: 4.1522
# Epoch 912 | Training loss: 4.1387
# Epoch 913 | Training loss: 4.1378
# Epoch 914 | Training loss: 4.1301
# Epoch 914 | Eval loss: 4.4948
# Epoch 915 | Training loss: 4.1628
# Epoch 916 | Training loss: 4.1368
# Epoch 917 | Training loss: 4.1404
# Epoch 918 | Training loss: 4.1451
# Epoch 919 | Training loss: 4.1883
# Epoch 919 | Eval loss: 4.4787
# Epoch 920 | Training loss: 4.1701
# Epoch 921 | Training loss: 4.1541
# Epoch 922 | Training loss: 4.1392
# Epoch 923 | Training loss: 4.1551
# Epoch 924 | Training loss: 4.1577
# Epoch 924 | Eval loss: 4.4227
# Epoch 925 | Training loss: 4.1400
# Epoch 926 | Training loss: 4.1283
# Epoch 927 | Training loss: 4.1641
# Epoch 928 | Training loss: 4.1341
# Epoch 929 | Training loss: 4.1512
# Epoch 929 | Eval loss: 4.4952
# Epoch 930 | Training loss: 4.1366
# Epoch 931 | Training loss: 4.1303
# Epoch 932 | Training loss: 4.1456
# Epoch 933 | Training loss: 4.1476
# Epoch 934 | Training loss: 4.1623
# Epoch 934 | Eval loss: 4.5900
# Epoch 935 | Training loss: 4.1420
# Epoch 936 | Training loss: 4.1424
# Epoch 937 | Training loss: 4.1399
# Epoch 938 | Training loss: 4.1518
# Epoch 939 | Training loss: 4.1363
# Epoch 939 | Eval loss: 4.5015
# Epoch 940 | Training loss: 4.1453
# Epoch 941 | Training loss: 4.1622
# Epoch 942 | Training loss: 4.1281
# Epoch 943 | Training loss: 4.1604
# Epoch 944 | Training loss: 4.1332
# Epoch 944 | Eval loss: 4.5994
# Epoch 945 | Training loss: 4.1319
# Epoch 946 | Training loss: 4.1356
# Epoch 947 | Training loss: 4.1438
# Epoch 948 | Training loss: 4.1504
# Epoch 949 | Training loss: 4.1573
# Epoch 949 | Eval loss: 4.5877
# Epoch 950 | Training loss: 4.1517
# Epoch 951 | Training loss: 4.1942
# Epoch 952 | Training loss: 4.1438
# Epoch 953 | Training loss: 4.1539
# Epoch 954 | Training loss: 4.1485
# Epoch 954 | Eval loss: 4.4839
# Epoch 955 | Training loss: 4.1423
# Epoch 956 | Training loss: 4.1644
# Epoch 957 | Training loss: 4.1566
# Epoch 958 | Training loss: 4.1426
# Epoch 959 | Training loss: 4.1471
# Epoch 959 | Eval loss: 4.5032
# Epoch 960 | Training loss: 4.1442
# Epoch 961 | Training loss: 4.1459
# Epoch 962 | Training loss: 4.1557
# Epoch 963 | Training loss: 4.1316
# Epoch 964 | Training loss: 4.1594
# Epoch 964 | Eval loss: 4.6356
# Epoch 965 | Training loss: 4.1584
# Epoch 966 | Training loss: 4.1339
# Epoch 967 | Training loss: 4.1711
# Epoch 968 | Training loss: 4.1530
# Epoch 969 | Training loss: 4.1430
# Epoch 969 | Eval loss: 4.5984
# Epoch 970 | Training loss: 4.1303
# Epoch 971 | Training loss: 4.1497
# Epoch 972 | Training loss: 4.1559
# Epoch 973 | Training loss: 4.1556
# Epoch 974 | Training loss: 4.1683
# Epoch 974 | Eval loss: 4.6381
# Epoch 975 | Training loss: 4.1593
# Epoch 976 | Training loss: 4.1384
# Epoch 977 | Training loss: 4.1696
# Epoch 978 | Training loss: 4.1393
# Epoch 979 | Training loss: 4.1499
# Epoch 979 | Eval loss: 4.5468
# Epoch 980 | Training loss: 4.1394
# Epoch 981 | Training loss: 4.1644
# Epoch 982 | Training loss: 4.1455
# Epoch 983 | Training loss: 4.1365
# Epoch 984 | Training loss: 4.1400
# Epoch 984 | Eval loss: 4.6813
# Epoch 985 | Training loss: 4.1718
# Epoch 986 | Training loss: 4.1643
# Epoch 987 | Training loss: 4.1430
# Epoch 988 | Training loss: 4.1410
# Epoch 989 | Training loss: 4.1477
# Epoch 989 | Eval loss: 4.5346
# Epoch 990 | Training loss: 4.1784
# Epoch 991 | Training loss: 4.1501
# Epoch 992 | Training loss: 4.1496
# Epoch 993 | Training loss: 4.1658
# Epoch 994 | Training loss: 4.1848
# Epoch 994 | Eval loss: 4.6994
# Epoch 995 | Training loss: 4.1258
# Epoch 996 | Training loss: 4.1525
# Epoch 997 | Training loss: 4.1643
# Epoch 998 | Training loss: 4.1339
# Epoch 999 | Training loss: 4.1349
# Epoch 999 | Eval loss: 4.7997
# Epoch 1000 | Training loss: 4.1461
# Epoch 1001 | Training loss: 4.1433
# Epoch 1002 | Training loss: 4.1884
# Epoch 1003 | Training loss: 4.1408
# Epoch 1004 | Training loss: 4.1387
# Epoch 1004 | Eval loss: 4.4796
# Epoch 1005 | Training loss: 4.1335
# Epoch 1006 | Training loss: 4.1340
# Epoch 1007 | Training loss: 4.1340
# Epoch 1008 | Training loss: 4.1486
# Epoch 1009 | Training loss: 4.1542
# Epoch 1009 | Eval loss: 4.6006
# Epoch 1010 | Training loss: 4.1345
# Epoch 1011 | Training loss: 4.1456
# Epoch 1012 | Training loss: 4.1503
# Epoch 1013 | Training loss: 4.1415
# Epoch 1014 | Training loss: 4.1439
# Epoch 1014 | Eval loss: 4.7107
# Epoch 1015 | Training loss: 4.1674
# Epoch 1016 | Training loss: 4.1463
# Epoch 1017 | Training loss: 4.1441
# Epoch 1018 | Training loss: 4.1560
# Epoch 1019 | Training loss: 4.1532
# Epoch 1019 | Eval loss: 4.5960
# Epoch 1020 | Training loss: 4.1443
# Epoch 1021 | Training loss: 4.1270
# Epoch 1022 | Training loss: 4.1369
# Epoch 1023 | Training loss: 4.1425
# Epoch 1024 | Training loss: 4.1410
# Epoch 1024 | Eval loss: 4.5847
# Epoch 1025 | Training loss: 4.1298
# Epoch 1026 | Training loss: 4.1513
# Epoch 1027 | Training loss: 4.1345
# Epoch 1028 | Training loss: 4.1447
# Epoch 1029 | Training loss: 4.1465
# Epoch 1029 | Eval loss: 4.6584
# Epoch 1030 | Training loss: 4.1436
# Epoch 1031 | Training loss: 4.1320
# Epoch 1032 | Training loss: 4.1395
# Epoch 1033 | Training loss: 4.1694
# Epoch 1034 | Training loss: 4.1493
# Epoch 1034 | Eval loss: 4.5263
# Epoch 1035 | Training loss: 4.1462
# Epoch 1036 | Training loss: 4.1623
# Epoch 1037 | Training loss: 4.1617
# Epoch 1038 | Training loss: 4.1460
# Epoch 1039 | Training loss: 4.1530
# Epoch 1039 | Eval loss: 4.4456
# Epoch 1040 | Training loss: 4.1316
# Epoch 1041 | Training loss: 4.1516
# Epoch 1042 | Training loss: 4.1367
# Epoch 1043 | Training loss: 4.1348
# Epoch 1044 | Training loss: 4.1376
# Epoch 1044 | Eval loss: 4.6756
# Epoch 1045 | Training loss: 4.1347
# Epoch 1046 | Training loss: 4.1395
# Epoch 1047 | Training loss: 4.1351
# Epoch 1048 | Training loss: 4.1859
# Epoch 1049 | Training loss: 4.1554
# Epoch 1049 | Eval loss: 4.4837
# Epoch 1050 | Training loss: 4.1583
# Epoch 1051 | Training loss: 4.1557
# Epoch 1052 | Training loss: 4.1520
# Epoch 1053 | Training loss: 4.1599
# Epoch 1054 | Training loss: 4.1413
# Epoch 1054 | Eval loss: 4.5579
# Epoch 1055 | Training loss: 4.1404
# Epoch 1056 | Training loss: 4.1327
# Epoch 1057 | Training loss: 4.1414
# Epoch 1058 | Training loss: 4.1402
# Epoch 1059 | Training loss: 4.1500
# Epoch 1059 | Eval loss: 4.7284
# Epoch 1060 | Training loss: 4.1431
# Epoch 1061 | Training loss: 4.1566
# Epoch 1062 | Training loss: 4.1319
# Epoch 1063 | Training loss: 4.1472
# Epoch 1064 | Training loss: 4.1347
# Epoch 1064 | Eval loss: 4.4137
# Epoch 1065 | Training loss: 4.1423
# Epoch 1066 | Training loss: 4.1330
# Epoch 1067 | Training loss: 4.1459
# Epoch 1068 | Training loss: 4.1538
# Epoch 1069 | Training loss: 4.1552
# Epoch 1069 | Eval loss: 4.6439
# Epoch 1070 | Training loss: 4.1685
# Epoch 1071 | Training loss: 4.1425
# Epoch 1072 | Training loss: 4.1317
# Epoch 1073 | Training loss: 4.1578
# Epoch 1074 | Training loss: 4.1466
# Epoch 1074 | Eval loss: 4.7977
# Epoch 1075 | Training loss: 4.1357
# Epoch 1076 | Training loss: 4.1350
# Epoch 1077 | Training loss: 4.1407
# Epoch 1078 | Training loss: 4.1442
# Epoch 1079 | Training loss: 4.1477
# Epoch 1079 | Eval loss: 4.6542
# Epoch 1080 | Training loss: 4.1688
# Epoch 1081 | Training loss: 4.1477
# Epoch 1082 | Training loss: 4.1369
# Epoch 1083 | Training loss: 4.1413
# Epoch 1084 | Training loss: 4.1651
# Epoch 1084 | Eval loss: 4.5343
# Epoch 1085 | Training loss: 4.1305
# Epoch 1086 | Training loss: 4.1379
# Epoch 1087 | Training loss: 4.1329
# Epoch 1088 | Training loss: 4.1571
# Epoch 1089 | Training loss: 4.1756
# Epoch 1089 | Eval loss: 4.6194
# Epoch 1090 | Training loss: 4.1629
# Epoch 1091 | Training loss: 4.1650
# Epoch 1092 | Training loss: 4.1357
# Epoch 1093 | Training loss: 4.1228
# Epoch 1094 | Training loss: 4.1339
# Epoch 1094 | Eval loss: 4.7192
# Epoch 1095 | Training loss: 4.1549
# Epoch 1096 | Training loss: 4.1697
# Epoch 1097 | Training loss: 4.1342
# Epoch 1098 | Training loss: 4.1303
# Epoch 1099 | Training loss: 4.1397
# Epoch 1099 | Eval loss: 4.6149
# Epoch 1100 | Training loss: 4.1594
# Epoch 1101 | Training loss: 4.1580
# Epoch 1102 | Training loss: 4.1537
# Epoch 1103 | Training loss: 4.1653
# Epoch 1104 | Training loss: 4.1432
# Epoch 1104 | Eval loss: 4.5690
# Epoch 1105 | Training loss: 4.1411
# Epoch 1106 | Training loss: 4.1576
# Epoch 1107 | Training loss: 4.1346
# Epoch 1108 | Training loss: 4.1496
# Epoch 1109 | Training loss: 4.1488
# Epoch 1109 | Eval loss: 4.5569
# Epoch 1110 | Training loss: 4.1369
# Epoch 1111 | Training loss: 4.1356
# Epoch 1112 | Training loss: 4.1527
# Epoch 1113 | Training loss: 4.1474
# Epoch 1114 | Training loss: 4.1438
# Epoch 1114 | Eval loss: 4.4601
# Epoch 1115 | Training loss: 4.1401
# Epoch 1116 | Training loss: 4.1455
# Epoch 1117 | Training loss: 4.1757
# Epoch 1118 | Training loss: 4.1252
# Epoch 1119 | Training loss: 4.1728
# Epoch 1119 | Eval loss: 4.5288
# Epoch 1120 | Training loss: 4.1507
# Epoch 1121 | Training loss: 4.1593
# Epoch 1122 | Training loss: 4.1657
# Epoch 1123 | Training loss: 4.1551
# Epoch 1124 | Training loss: 4.1331
# Epoch 1124 | Eval loss: 4.6167
# Epoch 1125 | Training loss: 4.1440
# Epoch 1126 | Training loss: 4.1496
# Epoch 1127 | Training loss: 4.1523
# Epoch 1128 | Training loss: 4.1377
# Epoch 1129 | Training loss: 4.1600
# Epoch 1129 | Eval loss: 4.7165
# Epoch 1130 | Training loss: 4.1513
# Epoch 1131 | Training loss: 4.1376
# Epoch 1132 | Training loss: 4.1376
# Epoch 1133 | Training loss: 4.1449
# Epoch 1134 | Training loss: 4.1533
# Epoch 1134 | Eval loss: 4.6826
# Epoch 1135 | Training loss: 4.1604
# Epoch 1136 | Training loss: 4.1749
# Epoch 1137 | Training loss: 4.1334
# Epoch 1138 | Training loss: 4.1554
# Epoch 1139 | Training loss: 4.1347
# Epoch 1139 | Eval loss: 4.6762
# Epoch 1140 | Training loss: 4.1373
# Epoch 1141 | Training loss: 4.1306
# Epoch 1142 | Training loss: 4.1406
# Epoch 1143 | Training loss: 4.1434
# Epoch 1144 | Training loss: 4.1561
# Epoch 1144 | Eval loss: 4.5730
# Epoch 1145 | Training loss: 4.1362
# Epoch 1146 | Training loss: 4.1348
# Epoch 1147 | Training loss: 4.1452
# Epoch 1148 | Training loss: 4.1808
# Epoch 1149 | Training loss: 4.1621
# Epoch 1149 | Eval loss: 4.6670
# Epoch 1150 | Training loss: 4.1316
# Epoch 1151 | Training loss: 4.1533
# Epoch 1152 | Training loss: 4.1369
# Epoch 1153 | Training loss: 4.1289
# Epoch 1154 | Training loss: 4.1400
# Epoch 1154 | Eval loss: 4.7244
# Epoch 1155 | Training loss: 4.1293
# Epoch 1156 | Training loss: 4.1360
# Epoch 1157 | Training loss: 4.1704
# Epoch 1158 | Training loss: 4.1488
# Epoch 1159 | Training loss: 4.1438
# Epoch 1159 | Eval loss: 4.6446
# Epoch 1160 | Training loss: 4.1518
# Epoch 1161 | Training loss: 4.1399
# Epoch 1162 | Training loss: 4.1418
# Epoch 1163 | Training loss: 4.1571
# Epoch 1164 | Training loss: 4.1538
# Epoch 1164 | Eval loss: 4.5588
# Epoch 1165 | Training loss: 4.1375
# Epoch 1166 | Training loss: 4.1241
# Epoch 1167 | Training loss: 4.1455
# Epoch 1168 | Training loss: 4.1686
# Epoch 1169 | Training loss: 4.1705
# Epoch 1169 | Eval loss: 4.6087
# Epoch 1170 | Training loss: 4.1650
# Epoch 1171 | Training loss: 4.1438
# Epoch 1172 | Training loss: 4.1386
# Epoch 1173 | Training loss: 4.1150
# Epoch 1174 | Training loss: 4.1396
# Epoch 1174 | Eval loss: 4.5790
# Epoch 1175 | Training loss: 4.1310
# Epoch 1176 | Training loss: 4.1140
# Epoch 1177 | Training loss: 4.1412
# Epoch 1178 | Training loss: 4.1500
# Epoch 1179 | Training loss: 4.1785
# Epoch 1179 | Eval loss: 4.4764
# Epoch 1180 | Training loss: 4.1470
# Epoch 1181 | Training loss: 4.1465
# Epoch 1182 | Training loss: 4.1449
# Epoch 1183 | Training loss: 4.1528
# Epoch 1184 | Training loss: 4.1733
# Epoch 1184 | Eval loss: 4.6027
# Epoch 1185 | Training loss: 4.1615
# Epoch 1186 | Training loss: 4.1325
# Epoch 1187 | Training loss: 4.1411
# Epoch 1188 | Training loss: 4.1286
# Epoch 1189 | Training loss: 4.1324
# Epoch 1189 | Eval loss: 4.5084
# Epoch 1190 | Training loss: 4.1398
# Epoch 1191 | Training loss: 4.1432
# Epoch 1192 | Training loss: 4.1209
# Epoch 1193 | Training loss: 4.1473
# Epoch 1194 | Training loss: 4.1350
# Epoch 1194 | Eval loss: 4.6278
# Epoch 1195 | Training loss: 4.1622
# ...
# Epoch 1613 | Training loss: 4.1321
# Epoch 1614 | Training loss: 4.1478
# Epoch 1614 | Eval loss: 4.6691
# Epoch 1615 | Training loss: 4.1541
# Epoch 1616 | Training loss: 4.1386
# Epoch 1617 | Training loss: 4.1294
# Epoch 1618 | Training loss: 4.1238
# Epoch 1619 | Training loss: 4.1366
# Epoch 1619 | Eval loss: 4.5876
# Epoch 1620 | Training loss: 4.1335
# Epoch 1621 | Training loss: 4.1453
# Epoch 1622 | Training loss: 4.1447
# Epoch 1623 | Training loss: 4.1374
# Epoch 1624 | Training loss: 4.1551
# Epoch 1624 | Eval loss: 4.5138
# Epoch 1625 | Training loss: 4.1166
# Epoch 1626 | Training loss: 4.1361
# Epoch 1627 | Training loss: 4.1285
# Epoch 1628 | Training loss: 4.1324
# Epoch 1629 | Training loss: 4.1268
# Epoch 1629 | Eval loss: 4.6313
# Epoch 1630 | Training loss: 4.1276
# Epoch 1631 | Training loss: 4.1143
# Epoch 1632 | Training loss: 4.1348
# Epoch 1633 | Training loss: 4.1301
# Epoch 1634 | Training loss: 4.1507
# Epoch 1634 | Eval loss: 4.5626
# Epoch 1635 | Training loss: 4.1655
# Epoch 1636 | Training loss: 4.1497
# Epoch 1637 | Training loss: 4.1373
# Epoch 1638 | Training loss: 4.1463
# Epoch 1639 | Training loss: 4.1228
# Epoch 1639 | Eval loss: 4.5359
# Epoch 1640 | Training loss: 4.1395
# Epoch 1641 | Training loss: 4.1263
# Epoch 1642 | Training loss: 4.1328
# Epoch 1643 | Training loss: 4.1366
# Epoch 1644 | Training loss: 4.1487
# Epoch 1644 | Eval loss: 4.5098
# Epoch 1645 | Training loss: 4.1296
# Epoch 1646 | Training loss: 4.1473
# Epoch 1647 | Training loss: 4.1297
# Epoch 1648 | Training loss: 4.1249
# Epoch 1649 | Training loss: 4.1598
# Epoch 1649 | Eval loss: 4.7029
# Epoch 1650 | Training loss: 4.1467
# Epoch 1651 | Training loss: 4.1307
# Epoch 1652 | Training loss: 4.1386
# Epoch 1653 | Training loss: 4.1446
# Epoch 1654 | Training loss: 4.1450
# Epoch 1654 | Eval loss: 4.5405
# Epoch 1655 | Training loss: 4.1154
# Epoch 1656 | Training loss: 4.1336
# Epoch 1657 | Training loss: 4.1307
# Epoch 1658 | Training loss: 4.1153
# Epoch 1659 | Training loss: 4.1398
# Epoch 1659 | Eval loss: 4.5482
# Epoch 1660 | Training loss: 4.1265
# Epoch 1661 | Training loss: 4.1204
# Epoch 1662 | Training loss: 4.1430
# Epoch 1663 | Training loss: 4.1378
# Epoch 1664 | Training loss: 4.1417
# Epoch 1664 | Eval loss: 4.4380
# Epoch 1665 | Training loss: 4.1251
# Epoch 1666 | Training loss: 4.1499
# Epoch 1667 | Training loss: 4.1652
# Epoch 1668 | Training loss: 4.1283
# Epoch 1669 | Training loss: 4.1267
# Epoch 1669 | Eval loss: 4.7265
# Epoch 1670 | Training loss: 4.1740
# Epoch 1671 | Training loss: 4.1335
# Epoch 1672 | Training loss: 4.1381
# Epoch 1673 | Training loss: 4.1277
# Epoch 1674 | Training loss: 4.1315
# Epoch 1674 | Eval loss: 4.4702
# Epoch 1675 | Training loss: 4.1333
# Epoch 1676 | Training loss: 4.1394
# Epoch 1677 | Training loss: 4.1486
# Epoch 1678 | Training loss: 4.1349
# Epoch 1679 | Training loss: 4.1359
# Epoch 1679 | Eval loss: 4.6191
# Epoch 1680 | Training loss: 4.1182
# Epoch 1681 | Training loss: 4.1337
# Epoch 1682 | Training loss: 4.1401
# Epoch 1683 | Training loss: 4.1470
# Epoch 1684 | Training loss: 4.1346
# Epoch 1684 | Eval loss: 4.5833
# Epoch 1685 | Training loss: 4.1220
# Epoch 1686 | Training loss: 4.1248
# Epoch 1687 | Training loss: 4.1412
# Epoch 1688 | Training loss: 4.1192
# Epoch 1689 | Training loss: 4.1360
# Epoch 1689 | Eval loss: 4.5634
# Epoch 1690 | Training loss: 4.1271
# Epoch 1691 | Training loss: 4.1308
# Epoch 1692 | Training loss: 4.1194
# Epoch 1693 | Training loss: 4.1192
# Epoch 1694 | Training loss: 4.1308
# Epoch 1694 | Eval loss: 4.6211
# Epoch 1695 | Training loss: 4.1216
# Epoch 1696 | Training loss: 4.1126
# Epoch 1697 | Training loss: 4.1227
# Epoch 1698 | Training loss: 4.1412
# Epoch 1699 | Training loss: 4.1302
# Epoch 1699 | Eval loss: 4.6263
# Epoch 1700 | Training loss: 4.1236
# Epoch 1701 | Training loss: 4.1205
# Epoch 1702 | Training loss: 4.1431
# Epoch 1703 | Training loss: 4.1355
# Epoch 1704 | Training loss: 4.1475
# Epoch 1704 | Eval loss: 4.5824
# Epoch 1705 | Training loss: 4.1387
# Epoch 1706 | Training loss: 4.1199
# Epoch 1707 | Training loss: 4.1198
# Epoch 1708 | Training loss: 4.1548
# Epoch 1709 | Training loss: 4.1409
# Epoch 1709 | Eval loss: 4.6444
# Epoch 1710 | Training loss: 4.1546
# Epoch 1711 | Training loss: 4.1257
# Epoch 1712 | Training loss: 4.1310
# Epoch 1713 | Training loss: 4.1193
# Epoch 1714 | Training loss: 4.1225
# Epoch 1714 | Eval loss: 4.5286
# Epoch 1715 | Training loss: 4.1273
# Epoch 1716 | Training loss: 4.1211
# Epoch 1717 | Training loss: 4.1333
# Epoch 1718 | Training loss: 4.1315
# Epoch 1719 | Training loss: 4.1290
# Epoch 1719 | Eval loss: 4.7409
# Epoch 1720 | Training loss: 4.1386
# Epoch 1721 | Training loss: 4.1437
# Epoch 1722 | Training loss: 4.1396
# Epoch 1723 | Training loss: 4.1343
# Epoch 1724 | Training loss: 4.1373
# Epoch 1724 | Eval loss: 4.7038
# Epoch 1725 | Training loss: 4.1132
# Epoch 1726 | Training loss: 4.1344
# Epoch 1727 | Training loss: 4.1280
# Epoch 1728 | Training loss: 4.1321
# Epoch 1729 | Training loss: 4.1064
# Epoch 1729 | Eval loss: 4.4984
# Epoch 1730 | Training loss: 4.1351
# Epoch 1731 | Training loss: 4.1235
# Epoch 1732 | Training loss: 4.1354
# Epoch 1733 | Training loss: 4.1372
# Epoch 1734 | Training loss: 4.1415
# Epoch 1734 | Eval loss: 4.6521
# Epoch 1735 | Training loss: 4.1372
# Epoch 1736 | Training loss: 4.1174
# Epoch 1737 | Training loss: 4.1147
# Epoch 1738 | Training loss: 4.1505
# Epoch 1739 | Training loss: 4.1122
# Epoch 1739 | Eval loss: 4.4792
# Epoch 1740 | Training loss: 4.1345
# Epoch 1741 | Training loss: 4.1352
# Epoch 1742 | Training loss: 4.1236
# Epoch 1743 | Training loss: 4.1222
# Epoch 1744 | Training loss: 4.1046
# Epoch 1744 | Eval loss: 4.4991
# Epoch 1745 | Training loss: 4.1224
# Epoch 1746 | Training loss: 4.1554
# Epoch 1747 | Training loss: 4.1441
# Epoch 1748 | Training loss: 4.1215
# Epoch 1749 | Training loss: 4.1239
# Epoch 1749 | Eval loss: 4.4861
# Epoch 1750 | Training loss: 4.1322
# Epoch 1751 | Training loss: 4.1373
# Epoch 1752 | Training loss: 4.1159
# Epoch 1753 | Training loss: 4.1501
# Epoch 1754 | Training loss: 4.1291
# Epoch 1754 | Eval loss: 4.6741
# Epoch 1755 | Training loss: 4.1117
# Epoch 1756 | Training loss: 4.1012
# Epoch 1757 | Training loss: 4.1261
# Epoch 1758 | Training loss: 4.1438
# Epoch 1759 | Training loss: 4.1136
# Epoch 1759 | Eval loss: 4.5431
# Epoch 1760 | Training loss: 4.1198
# Epoch 1761 | Training loss: 4.1278
# Epoch 1762 | Training loss: 4.1220
# Epoch 1763 | Training loss: 4.1278
# Epoch 1764 | Training loss: 4.1180
# Epoch 1764 | Eval loss: 4.6259
# Epoch 1765 | Training loss: 4.1249
# Epoch 1766 | Training loss: 4.1126
# Epoch 1767 | Training loss: 4.1151
# Epoch 1768 | Training loss: 4.1625
# Epoch 1769 | Training loss: 4.1322
# Epoch 1769 | Eval loss: 4.5755
# Epoch 1770 | Training loss: 4.1219
# Epoch 1771 | Training loss: 4.1123
# Epoch 1772 | Training loss: 4.1346
# Epoch 1773 | Training loss: 4.1304
# Epoch 1774 | Training loss: 4.1348
# Epoch 1774 | Eval loss: 4.7376
# Epoch 1775 | Training loss: 4.1348
# Epoch 1776 | Training loss: 4.1266
# Epoch 1777 | Training loss: 4.1229
# Epoch 1778 | Training loss: 4.1499
# Epoch 1779 | Training loss: 4.1283
# Epoch 1779 | Eval loss: 4.6027
# Epoch 1780 | Training loss: 4.1343
# Epoch 1781 | Training loss: 4.1326
# Epoch 1782 | Training loss: 4.1314
# Epoch 1783 | Training loss: 4.1305
# Epoch 1784 | Training loss: 4.1391
# Epoch 1784 | Eval loss: 4.4891
# Epoch 1785 | Training loss: 4.1327
# Epoch 1786 | Training loss: 4.1351
# Epoch 1787 | Training loss: 4.1736
# Epoch 1788 | Training loss: 4.1376
# Epoch 1789 | Training loss: 4.1245
# Epoch 1789 | Eval loss: 4.5176
# Epoch 1790 | Training loss: 4.1248
# Epoch 1791 | Training loss: 4.1088
# Epoch 1792 | Training loss: 4.1298
# Epoch 1793 | Training loss: 4.1235
# Epoch 1794 | Training loss: 4.1209
# Epoch 1794 | Eval loss: 4.5469
# Epoch 1795 | Training loss: 4.1408
# Epoch 1796 | Training loss: 4.1226
# Epoch 1797 | Training loss: 4.1258
# Epoch 1798 | Training loss: 4.1359
# Epoch 1799 | Training loss: 4.1243
# Epoch 1799 | Eval loss: 4.6370
# Epoch 1800 | Training loss: 4.1421
# Epoch 1801 | Training loss: 4.1101
# Epoch 1802 | Training loss: 4.1243
# Epoch 1803 | Training loss: 4.1504
# Epoch 1804 | Training loss: 4.1197
# Epoch 1804 | Eval loss: 4.5077
# Epoch 1805 | Training loss: 4.1339
# Epoch 1806 | Training loss: 4.1372
# Epoch 1807 | Training loss: 4.1144
# Epoch 1808 | Training loss: 4.1138
# Epoch 1809 | Training loss: 4.1301
# Epoch 1809 | Eval loss: 4.4628
# Epoch 1810 | Training loss: 4.1346
# Epoch 1811 | Training loss: 4.1170
# Epoch 1812 | Training loss: 4.1260
# Epoch 1813 | Training loss: 4.1248
# Epoch 1814 | Training loss: 4.1278
# Epoch 1814 | Eval loss: 4.4948
# Epoch 1815 | Training loss: 4.1160
# Epoch 1816 | Training loss: 4.1421
# Epoch 1817 | Training loss: 4.1461
# Epoch 1818 | Training loss: 4.1238
# Epoch 1819 | Training loss: 4.1565
# Epoch 1819 | Eval loss: 4.6100
# Epoch 1820 | Training loss: 4.1341
# Epoch 1821 | Training loss: 4.1206
# Epoch 1822 | Training loss: 4.1221
# Epoch 1823 | Training loss: 4.1460
# Epoch 1824 | Training loss: 4.1207
# Epoch 1824 | Eval loss: 4.7232
# Epoch 1825 | Training loss: 4.1278
# Epoch 1826 | Training loss: 4.1273
# Epoch 1827 | Training loss: 4.1279
# Epoch 1828 | Training loss: 4.1445
# Epoch 1829 | Training loss: 4.1566
# Epoch 1829 | Eval loss: 4.5050
# Epoch 1830 | Training loss: 4.1349
# Epoch 1831 | Training loss: 4.1358
# Epoch 1832 | Training loss: 4.1370
# Epoch 1833 | Training loss: 4.1319
# Epoch 1834 | Training loss: 4.1225
# Epoch 1834 | Eval loss: 4.6338
# Epoch 1835 | Training loss: 4.1234
# Epoch 1836 | Training loss: 4.1261
# Epoch 1837 | Training loss: 4.1208
# Epoch 1838 | Training loss: 4.1437
# Epoch 1839 | Training loss: 4.1057
# Epoch 1839 | Eval loss: 4.5236
# Epoch 1840 | Training loss: 4.1211
# Epoch 1841 | Training loss: 4.1334
# Epoch 1842 | Training loss: 4.1471
# Epoch 1843 | Training loss: 4.1422
# Epoch 1844 | Training loss: 4.1486
# Epoch 1844 | Eval loss: 4.6021
# Epoch 1845 | Training loss: 4.1346
# Epoch 1846 | Training loss: 4.1451
# Epoch 1847 | Training loss: 4.1361
# Epoch 1848 | Training loss: 4.1338
# Epoch 1849 | Training loss: 4.1184
# Epoch 1849 | Eval loss: 4.4889
# Epoch 1850 | Training loss: 4.1342
# Epoch 1851 | Training loss: 4.1310
# Epoch 1852 | Training loss: 4.1431
# Epoch 1853 | Training loss: 4.1370
# Epoch 1854 | Training loss: 4.1484
# Epoch 1854 | Eval loss: 4.6800
# Epoch 1855 | Training loss: 4.1173
# Epoch 1856 | Training loss: 4.1358
# Epoch 1857 | Training loss: 4.1406
# Epoch 1858 | Training loss: 4.1290
# Epoch 1859 | Training loss: 4.1132
# Epoch 1859 | Eval loss: 4.6375
# Epoch 1860 | Training loss: 4.1181
# Epoch 1861 | Training loss: 4.1245
# Epoch 1862 | Training loss: 4.1112
# Epoch 1863 | Training loss: 4.1331
# Epoch 1864 | Training loss: 4.1330
# Epoch 1864 | Eval loss: 4.4818
# Epoch 1865 | Training loss: 4.1165
# Epoch 1866 | Training loss: 4.1200
# Epoch 1867 | Training loss: 4.1374
# Epoch 1868 | Training loss: 4.1083
# Epoch 1869 | Training loss: 4.1161
# Epoch 1869 | Eval loss: 4.4227
# Epoch 1870 | Training loss: 4.1333
# Epoch 1871 | Training loss: 4.1684
# Epoch 1872 | Training loss: 4.1230
# Epoch 1873 | Training loss: 4.1297
# Epoch 1874 | Training loss: 4.1243
# Epoch 1874 | Eval loss: 4.6579
# Epoch 1875 | Training loss: 4.1572
# Epoch 1876 | Training loss: 4.1066
# Epoch 1877 | Training loss: 4.1210
# Epoch 1878 | Training loss: 4.1159
# Epoch 1879 | Training loss: 4.1191
# Epoch 1879 | Eval loss: 4.6291
# Epoch 1880 | Training loss: 4.1371
# Epoch 1881 | Training loss: 4.1085
# Epoch 1882 | Training loss: 4.1169
# Epoch 1883 | Training loss: 4.1290
# Epoch 1884 | Training loss: 4.1371
# Epoch 1884 | Eval loss: 4.6512
# Epoch 1885 | Training loss: 4.1391
# Epoch 1886 | Training loss: 4.1189
# Epoch 1887 | Training loss: 4.1144
# Epoch 1888 | Training loss: 4.1185
# Epoch 1889 | Training loss: 4.1203
# Epoch 1889 | Eval loss: 4.5416
# Epoch 1890 | Training loss: 4.1141
# Epoch 1891 | Training loss: 4.1308
# Epoch 1892 | Training loss: 4.1229
# Epoch 1893 | Training loss: 4.1281
# Epoch 1894 | Training loss: 4.1280
# Epoch 1894 | Eval loss: 4.5466
# Epoch 1895 | Training loss: 4.1149
# Epoch 1896 | Training loss: 4.1281
# Epoch 1897 | Training loss: 4.1205
# Epoch 1898 | Training loss: 4.1273
# Epoch 1899 | Training loss: 4.1026
# Epoch 1899 | Eval loss: 4.5335
# Epoch 1900 | Training loss: 4.1199
# Epoch 1901 | Training loss: 4.1071
# Epoch 1902 | Training loss: 4.1213
# Epoch 1903 | Training loss: 4.1141
# Epoch 1904 | Training loss: 4.1292
# Epoch 1904 | Eval loss: 4.5149
# Epoch 1905 | Training loss: 4.1518
# Epoch 1906 | Training loss: 4.1436
# Epoch 1907 | Training loss: 4.1399
# Epoch 1908 | Training loss: 4.1416
# Epoch 1909 | Training loss: 4.1148
# Epoch 1909 | Eval loss: 4.5018
# Epoch 1910 | Training loss: 4.1210
# Epoch 1911 | Training loss: 4.1133
# Epoch 1912 | Training loss: 4.1423
# Epoch 1913 | Training loss: 4.1397
# Epoch 1914 | Training loss: 4.1325
# Epoch 1914 | Eval loss: 4.7193
# Epoch 1915 | Training loss: 4.1450
# Epoch 1916 | Training loss: 4.1214
# Epoch 1917 | Training loss: 4.1178
# Epoch 1918 | Training loss: 4.1243
# Epoch 1919 | Training loss: 4.1307
# Epoch 1919 | Eval loss: 4.6077
# Epoch 1920 | Training loss: 4.1865
# Epoch 1921 | Training loss: 4.1438
# Epoch 1922 | Training loss: 4.1316
# Epoch 1923 | Training loss: 4.1377
# Epoch 1924 | Training loss: 4.1247
# Epoch 1924 | Eval loss: 4.4981
# Epoch 1925 | Training loss: 4.1255
# Epoch 1926 | Training loss: 4.1224
# Epoch 1927 | Training loss: 4.1194
# Epoch 1928 | Training loss: 4.1180
# Epoch 1929 | Training loss: 4.1325
# Epoch 1929 | Eval loss: 4.4198
# Epoch 1930 | Training loss: 4.1418
# Epoch 1931 | Training loss: 4.1238
# Epoch 1932 | Training loss: 4.1438
# Epoch 1933 | Training loss: 4.1294
# Epoch 1934 | Training loss: 4.1347
# Epoch 1934 | Eval loss: 4.6005
# Epoch 1935 | Training loss: 4.1405
# Epoch 1936 | Training loss: 4.1439
# Epoch 1937 | Training loss: 4.1205
# Epoch 1938 | Training loss: 4.1285
# Epoch 1939 | Training loss: 4.1193
# Epoch 1939 | Eval loss: 4.6472
# Epoch 1940 | Training loss: 4.1277
# Epoch 1941 | Training loss: 4.1331
# Epoch 1942 | Training loss: 4.1219
# Epoch 1943 | Training loss: 4.1293
# Epoch 1944 | Training loss: 4.1098
# Epoch 1944 | Eval loss: 4.4952
# Epoch 1945 | Training loss: 4.1226
# Epoch 1946 | Training loss: 4.1296
# Epoch 1947 | Training loss: 4.1196
# Epoch 1948 | Training loss: 4.1131
# Epoch 1949 | Training loss: 4.1363
# Epoch 1949 | Eval loss: 4.4859
# Epoch 1950 | Training loss: 4.1337
# Epoch 1951 | Training loss: 4.1260
# Epoch 1952 | Training loss: 4.1495
# Epoch 1953 | Training loss: 4.1185
# Epoch 1954 | Training loss: 4.1148
# Epoch 1954 | Eval loss: 4.5325
# Epoch 1955 | Training loss: 4.1303
# Epoch 1956 | Training loss: 4.1399
# Epoch 1957 | Training loss: 4.1230
# Epoch 1958 | Training loss: 4.1264
# Epoch 1959 | Training loss: 4.1576
# Epoch 1959 | Eval loss: 4.6241
# Epoch 1960 | Training loss: 4.1530
# Epoch 1961 | Training loss: 4.1350
# Epoch 1962 | Training loss: 4.1265
# Epoch 1963 | Training loss: 4.1345
# Epoch 1964 | Training loss: 4.1462
# Epoch 1964 | Eval loss: 4.4939
# Epoch 1965 | Training loss: 4.1246
# Epoch 1966 | Training loss: 4.1198
# Epoch 1967 | Training loss: 4.1120
# Epoch 1968 | Training loss: 4.1441
# Epoch 1969 | Training loss: 4.1230
# Epoch 1969 | Eval loss: 4.5543
# Epoch 1970 | Training loss: 4.1271
# Epoch 1971 | Training loss: 4.1299
# Epoch 1972 | Training loss: 4.1200
# Epoch 1973 | Training loss: 4.1245
# Epoch 1974 | Training loss: 4.1403
# Epoch 1974 | Eval loss: 4.6140
# Epoch 1975 | Training loss: 4.1065
# Epoch 1976 | Training loss: 4.1237
# Epoch 1977 | Training loss: 4.1227
# Epoch 1978 | Training loss: 4.1304
# Epoch 1979 | Training loss: 4.1350
# Epoch 1979 | Eval loss: 4.6865
# Epoch 1980 | Training loss: 4.1444
# Epoch 1981 | Training loss: 4.1175
# Epoch 1982 | Training loss: 4.1195
# Epoch 1983 | Training loss: 4.1186
# Epoch 1984 | Training loss: 4.1122
# Epoch 1984 | Eval loss: 4.5548
# Epoch 1985 | Training loss: 4.1120
# Epoch 1986 | Training loss: 4.1156
# Epoch 1987 | Training loss: 4.1397
# Epoch 1988 | Training loss: 4.1318
# Epoch 1989 | Training loss: 4.1499
# Epoch 1989 | Eval loss: 4.5084
# Epoch 1990 | Training loss: 4.1164
# Epoch 1991 | Training loss: 4.1223
# Epoch 1992 | Training loss: 4.1084
# Epoch 1993 | Training loss: 4.1268
# Epoch 1994 | Training loss: 4.1257
# Epoch 1994 | Eval loss: 4.7321
# Epoch 1995 | Training loss: 4.1449
# Epoch 1996 | Training loss: 4.1365
# Epoch 1997 | Training loss: 4.1224
# Epoch 1998 | Training loss: 4.1314
# Epoch 1999 | Training loss: 4.1152
# Epoch 1999 | Eval loss: 4.4821
# Training time:3029.9636s

# %%
# logits[0:2,:,:]
# W
path=root+'data_1354ac_2022/feasgnn_trained_ac1354_04022022cold_unreg2.pickle'
# path=root+'data_1354ac_2022/feasgnn_trained_ac1354_04022022cold_unreg_good.pickle'
torch.save(net.state_dict(),path)

# %%
# print(len(loss_val))
# print(loss_val[0][0])
# # print(val_plt)
# print(logits.shape,eval_label.shape)

# %%
import matplotlib.pyplot as plt

val_len = len(loss_val)
print(val_len)
val_plt = np.zeros((2,val_len))
for i in range(val_len):
  val_plt[0,i] = loss_val[i][0]
  val_plt[1,i] = loss_val[i][1]

plt.figure()
plot_idx = np.arange(np.size(loss_optm))
# plt.plot(plot_idx,loss_optm,lw=2,label='training loss')
# plt.plot(val_plt[0,:],val_plt[1,:],lw=2,label='validation loss')
plt.plot(plot_idx[5:-1],loss_optm[5:-1],lw=2,label='training loss')
plt.plot(val_plt[0,1:],val_plt[1,1:],lw=2,label='validation loss')
plt.yscale("log")
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show(block=False)

# from datetime import datetime
# now=datetime.now()
# timestamp=now.strftime('%Y%d%m%H%M%S')
# path='/content/drive/MyDrive/gnn/dnn_pytorch/gnn_%s.pickle'%(timestamp)
# # torch.save(net.state_dict(),path)
# path='/content/drive/MyDrive/gnn/dnn_pytorch/gnn_118_%s.pickle'%(timestamp)
# torch.save(net.state_dict(),path)
# path = '/content/drive/MyDrive/gnn/dnn_pytorch/gnn_118_20212205071835.pickle'
# net.load_state_dict(torch.load(path))
# path=root+'./data_1354ac_2022/ac_v_S_feasgnn_0318.pickle'
# torch.save(net.state_dict(),path)
# Out:
# 400

# %% [markdown]
# # Evaluate the model w/ validation set

# %%
# local_batch, local_labels = local_batch.to(device), local_labels.to(device)
# print(local_batch.shape)
# x_test_feed = x_test_feed.unsqueeze_(-1).transpose(1,2)
# print(x_test_feed.shape)

# print(local_batch.shape)

# %%
# validation_set = Dataset(features=x_test, labels=y_test)
# validation_generator = torch.utils.data.DataLoader(validation_set, **params)
# for local_batch, local_labels in validation_generator:
#   # Transfer to GPU
#   local_batch, local_labels = local_batch.to(device), local_labels.to(device)
#   logits = net(local_batch)

n_test = 2000

x_test_feed = torch.from_numpy(np.transpose(x_test)).float()
x_test_feed = x_test_feed#.transpose(1,2)
x_test_feed = x_test_feed.to(device)
print('Validation dataset size:',x_test_feed.shape)
print('Number of validation set: ',n_test)
# y_pred = np.zeros((x_test_feed.shape))
# for i in range(n_test):
#   y_pred[i,:] = net(x_test_feed[i,:])
y_pred = net(x_test_feed)
# Out:
# Validation dataset size: torch.Size([1807, 6, 1354])
# Number of validation set:  2000

# %% [markdown]
# * Visualization

# %% [markdown]
#  - Visualize errors

# %%
y_pred1 = y_pred.cpu().detach()
y_pred1 = torch.squeeze(y_pred1,1).numpy().transpose()
print(y_test.shape)
# Out:
# (1354, 2, 1807)

# %%
# recover the original p.u. scale
# vy_deviation) * vy_scale
y_pred1[:,1,:] = y_pred1[:,1,:] / vy_scale + vy_deviation
y_test[:,1,:] = y_test[:,1,:] / vy_scale + vy_deviation

print(y_test.shape,y_pred1.shape)
# Out:
# (1354, 2, 1807) (1354, 2, 1807)

# %%
# for i in range(5):
#   print('sample',i)
#   print(y_test[:,i])
#   print(y_pred1[:,i])

# %%
n_test = np.size(y_test,2)
err_L2 = np.zeros(n_test)
err_Linf = np.zeros(n_test)
for i in range(n_test):
  err_L2[i] = np.linalg.norm(y_test[:,0,i] - y_pred1[:,0,i]) / np.linalg.norm(y_test[:,0,i])
  err_Linf[i] = np.max(np.abs(y_test[:,0,i] - y_pred1[:,0,i])) / np.max(np.abs(y_test[:,0,i]))

err_L2_v = np.zeros(n_test)
err_Linf_v = np.zeros(n_test)
for i in range(n_test):
  err_L2_v[i] = np.linalg.norm(y_test[:,1,i] - y_pred1[:,1,i]) / np.linalg.norm(y_test[:,1,i])
  err_Linf_v[i] = np.max(np.abs(y_test[:,1,i] - y_pred1[:,1,i])) / np.max(np.abs(y_test[:,1,i]))

# %%
print(err_L2.shape,err_Linf.shape)
# Out:
# (1807,) (1807,)

# %%
err_L2_mean = np.mean(err_L2)
err_Linf_mean = np.mean(err_Linf)
print('Price L2 mean:', err_L2_mean,'L_inf mean:', err_Linf_mean )
err_L2_mean_v = np.mean(err_L2_v)
err_Linf_mean_v = np.mean(err_Linf_v)
print('Voltage L2 mean:', err_L2_mean_v,'L_inf mean:', err_Linf_mean_v )

fig2 = plt.figure(figsize=(16, 16))
plt.subplot(2, 2, 1)
# plt.hist(np.abs(ga),bins = 10)
plt.plot(err_L2,'bo',markersize=0.5,label = 'L2 error')
plt.plot(err_Linf,'r^',markersize=0.5,label = 'Linf error')
plt.legend(loc="upper right")
plt.xlabel('sample index')
plt.ylabel('error')
plt.title('Normalized sample error')
plt.grid(True)
# error histogram
plt.subplot(2, 2, 2)
plt.hist(err_L2, bins = 50, facecolor='b', alpha=0.75,label = 'L2 error')
plt.hist(err_Linf, bins = 50, facecolor='g', alpha=0.75,label = 'Linf error')
plt.legend(loc="upper right")
plt.xlabel('sample error value')
plt.ylabel('frequency')
plt.title('Histogram of L_2 error')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.grid(True)

plt.subplot(2, 2, 3)
# plt.hist(np.abs(ga),bins = 10)
plt.plot(err_L2_v,'bo',markersize=0.5,label = 'L2 error')
plt.plot(err_Linf_v,'r^',markersize=0.5,label = 'Linf error')
plt.legend(loc="upper right")
plt.xlabel('sample index')
plt.ylabel('error')
plt.title('Normalized sample error')
plt.grid(True)
# error histogram
plt.subplot(2, 2, 4)
plt.hist(err_L2_v, bins = 50, facecolor='b', alpha=0.75,label = 'L2 error')
plt.hist(err_Linf_v, bins = 50, facecolor='g', alpha=0.75,label = 'Linf error')
plt.legend(loc="upper right")
plt.xlabel('sample error value')
plt.ylabel('frequency')
plt.title('Histogram of L_2 error')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.grid(True)

plt.show()
# Out:
# Price L2 mean: 0.036446683532038164 L_inf mean: 0.11858167578348175
# Voltage L2 mean: 0.005478581595742231 L_inf mean: 0.03026995133636676

# %%
print(y_pred1[:,1,:n_test].shape,y_test[:,1,:n_test].shape)
print('true range:',np.max(y_test[:,1,:n_test]),np.min(y_test[:,1,:n_test]))
print('predicted range',np.max(y_pred1[:,1,:n_test]),np.min(y_pred1[:,1,:n_test]))

fig3 = plt.figure(figsize=(16, 8))
flat_list1 = list(np.concatenate(y_test[:,1,:n_test]).flat)
flat_list2 = list(np.concatenate(y_pred1[:,1,:n_test]).flat)
plt.hist(flat_list1,bins = 100,label = 'true')

plt.hist(flat_list2,bins = 100,label = 'pred')
plt.legend(loc="upper right")
plt.grid(True)
plt.show()
# Out:
# (1354, 1807) (1354, 1807)
# true range: 1.1338 0.9608
# predicted range 1.107663 0.98970556

# %%
err_l2_new = [i for i in err_L2 if i < 1]
err_linf_new = [i for i in err_Linf if i < 1]
print(len(err_l2_new),'L2 mean:', np.mean(err_l2_new),len(err_linf_new),'L_inf mean:', np.mean(err_linf_new) )

fig2 = plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
# plt.hist(np.abs(ga),bins = 10)
plt.plot(err_l2_new,'bo',markersize=0.5,label = 'L2 error')
plt.plot(err_linf_new,'r^',markersize=0.5,label = 'Linf error')
plt.legend(loc="upper right")
plt.xlabel('sample index')
plt.ylabel('error')
plt.title('Normalized sample error w/out >1')
plt.grid(True)
# error histogram
plt.subplot(1, 2, 2)
plt.hist(err_l2_new, bins = 50, facecolor='b', alpha=0.75,label = 'L2 error')
plt.hist(err_linf_new, bins = 50, facecolor='g', alpha=0.75,label = 'Linf error')
plt.legend(loc="upper right")
plt.xlabel('sample error value')
plt.ylabel('frequency')
plt.title('Histogram of L_2 error  w/out >1')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.grid(True)
plt.show()
# Out:
# 1807 L2 mean: 0.036446683532038164 1807 L_inf mean: 0.11858167578348175

# %%
print(x_train.shape)
# print(x_train[:,:,1].transpose())
# print(np.max(gen_limit0),np.min(err_linf_new))
# Out:
# (1354, 6, 7224)

# %%
# y_test_copy
# y_pred1[:,index]

# %% [markdown]
# # Predict generation using $\pi$
# * Using predicted $\pi$ and find the active constraints in $p_G(i)$
# * For inactive $p_G(i)$ consider other methods like power flow balance

# %%
gen_limit0 = x[:,4,:].copy() # lin cost
print(gen_limit0.shape)

gen_idx = []
gen_idx = np.arange(n_bus)
# for i in range(n_bus):
#   if gen_limit0[i,0] > 0:
#     gen_idx.append(i)
print(type(gen_idx),len(gen_idx),gen_idx)
# Out:
# (1354, 9031)
# <class 'numpy.ndarray'> 1354 [   0    1    2 ... 1351 1352 1353]

# %%
# # get the generator index
# # generator cost data
# gen_cost0
# # generator limit data
# gen_limit0
# # LMP data
# lmp_data
# # generation data
# gen_data

load_data = x.copy()
load_data = load_data[:,:]
print(load_data.shape)
n_sample = np.size(load_data,2)

# predict the corredponding LMP
x_val_feed = torch.from_numpy(np.transpose(load_data)).float()
batch_size=2000
y_pred1=[]
with torch.no_grad():
  for idx in range(0,x_val_feed.shape[0],batch_size):
    current_batch=x_val_feed[idx:idx+batch_size]
    current_batch=current_batch.to(device)
    current_y=net(current_batch)
    current_y=current_y.cpu().detach()
    current_y=torch.squeeze(current_y,1).numpy().tolist()
    y_pred1+=current_y
y_pred1=np.array(y_pred1).transpose()

print('Dataset size:',x_val_feed.shape)
print('Number of validation points:: ',n_sample)

# net1 = net.cpu()
# y_pred = net1(x_val_feed)

# y_pred1 = y_pred.cpu().detach()
print('output size',y_pred1.shape)
# y_pred1 = torch.squ[]eeze(y_pred1,1).numpy().transpose()
print('reshaped size',y_pred1.shape)

# load_data = x.copy()
# print(load_data.shape)
# n_sample = np.size(load_data,2)

# x_val_feed = torch.from_numpy(np.transpose(load_data)).float()
# x_val_feed = x_val_feed.to(device)

# print('Dataset size:',x_val_feed.shape)
# print('Number of validation points:: ',n_sample)
# y_pred = net(x_val_feed) # predict the corredponding LMP

# y_pred1 = y_pred.cpu().detach()
# print('output size',y_pred1.shape)
# y_pred1 = torch.squeeze(y_pred1,1).numpy().transpose()
# print('reshaped size',y_pred1.shape)
# Out:
# (1354, 6, 9031)
# Dataset size: torch.Size([9031, 6, 1354])
# Number of validation points::  9031
# output size (1354, 2, 9031)
# reshaped size (1354, 2, 9031)

# %% [markdown]
# * Save results

# %%
import pickle

# %%
# dataset = {'lmp_pred': y_pred1, 'lmp_true': lmp_data}
# print('Pred:',y_pred1.shape,'True:',lmp_data.shape)

# file_name = 'dc118_lmp_prediction_p10'
# file_path = 'drive/My Drive/gnn/data/results/'
# file_dir = file_path + file_name + '.pickle'
# outfile = open(file_dir, 'wb')
# pickle.dump(dataset, outfile)
# outfile.close()

# %%
gen_cost0 = x[:,4,:].copy()
lmp_data = y[:,0,:].copy()

quadratic_a = x[:,5,:].copy()

profit_pred = y_pred1[:,0,:] - gen_cost0
print(np.min(np.abs(profit_pred)))

profit_true = lmp_data - gen_cost0
print(np.min(np.abs(profit_true)))

profit_pred=(y_pred1[:,0,:]-gen_cost0)/(quadratic_a+1e-10)/2
profit_true=(lmp_data-gen_cost0)/(quadratic_a+1e-10)/2
print(np.min(np.abs(profit_pred)))
print(np.min(np.abs(profit_true)))
# Out:
# 82.7795639038086
# 27.810000000000002
# 22.496040534561047
# 20.923131545873904

# %%
print(profit_pred.shape,profit_true.shape)
profit_err = profit_true - profit_pred

profit_err_l2 = np.zeros([n_sample,1])

for i in range(n_sample):
  profit_err_l2[i] = np.linalg.norm(profit_err[:,i])/np.linalg.norm(profit_true[:,i])
print(np.mean(profit_err_l2))

fig5 = plt.figure(figsize=(16, 8))
# error histogram
plt.hist(profit_err_l2, bins = 50, facecolor='b', alpha=0.75,label = 'L2 error')
# plt.hist(err_linf_new, bins = 50, facecolor='g', alpha=0.75,label = 'Linf error')
plt.legend(loc="upper right")
plt.xlabel('sample error value')
plt.ylabel('frequency')
plt.title('Histogram of L_2 error')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.grid(True)
plt.show()
# Out:
# (1354, 9031) (1354, 9031)
# 0.035581525165699075

# %%
p_pred_sort = np.reshape(profit_pred,n_bus*n_sample)
p_true_sort = np.reshape(profit_true,n_bus*n_sample)
print(p_pred_sort.shape)
# Out:
# (12227974,)

# %%
print(np.min(p_pred_sort),np.min(p_true_sort))
# Out:
# 22.496040534561047 20.923131545873904

# %%
fig2 = plt.figure(figsize=(8, 8))
plt.hist(p_pred_sort, bins = 50, facecolor='b', alpha=0.75,label = 'pred. profit')
plt.hist(p_true_sort, bins = 50, facecolor='g', alpha=0.75,label = 'true profit')
plt.legend(loc="upper right")
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('profit histogram')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.grid(True)
plt.show()

# %%
# gen_pred_binary = np.zeros((len(gen_idx),n_sample))
# gen_true_binary = np.zeros((len(gen_idx),n_sample))
# print(gen_pred_binary.shape)

# binary_thres = 2.5
# binary_thres_true = 1e-5

# for i in range(n_sample):
#   for j in range(len(gen_idx)):
#     # predicted generator limit
#     if profit_pred[gen_idx[j],i] > binary_thres:
#       gen_pred_binary[j,i] = 1
#     elif profit_pred[gen_idx[j],i] < 0:
#       gen_pred_binary[j,i] = 0
#     else:
#       # gen_pred_binary[j,i] = (profit_pred[gen_idx[j],i] + binary_thres) / (2*binary_thres)
#       gen_pred_binary[j,i] = (profit_pred[gen_idx[j],i]) / (binary_thres)
#     # true generator limit
#     if profit_true[gen_idx[j],i] > binary_thres_true:
#       gen_true_binary[j,i] = 1
#     elif profit_true[gen_idx[j],i] < 0:
#       gen_true_binary[j,i] = 0
#     else:
#       gen_true_binary[j,i] = 0.5

# gen_binary_err = np.abs(gen_true_binary - gen_pred_binary)
# print('max binary error:',np.max(gen_binary_err))
# # count the wrong entries
# gen_binary_err_ct = np.sum(gen_binary_err)
# gen_binary_err_ratio = gen_binary_err_ct / (len(gen_idx)*n_sample)
# print('Binary accuracy:',1-gen_binary_err_ratio)

# %%
print(gen_limit0.shape)
print(np.transpose(x_test).shape,np.transpose(load_data).shape)
# Out:
# (1354, 9031)
# (1807, 6, 1354) (9031, 6, 1354)

# %% [markdown]
#  # Test flow feasibility

# %%
x[:,2,:].shape
profit_pred.shape
# n_sample
# Out:
# (1354, 9031)

# %%
# x = [load, gen_cost, gen_lim]

# binary_thres = 0.97
binary_thres_true = 1e-5
# binary_thres = gen_limit0
binary_thres = x[:,0,:].copy() # upper
binary_thres_lo = x[:,1,:].copy() # lower

gen_pred_binary_full = np.zeros((n_bus,n_sample))
gen_true_binary_full = np.zeros((n_bus,n_sample))
# print(gen_pred_binary.shape,profit_pred.shape,gen_pred_binary_full.shape)

# x[:,2,:] # p_max

# ## generator injection
# for i in range(n_sample):
#   for j in range(len(gen_idx)):
#     # predicted generator limit
#     if profit_pred[gen_idx[j],i] > binary_thres[gen_idx[j],i]:
#       gen_pred_binary_full[gen_idx[j],i] = binary_thres[gen_idx[j],i]
#     elif profit_pred[gen_idx[j],i] < 0:
#       gen_pred_binary_full[gen_idx[j],i] = 0
#     else:
#       gen_pred_binary_full[gen_idx[j],i] = profit_pred[gen_idx[j],i]
#     # true generator limit
#     if profit_true[gen_idx[j],i] > binary_thres[gen_idx[j],i]:
#       gen_true_binary_full[gen_idx[j],i] = binary_thres[gen_idx[j],i]
#     elif profit_true[gen_idx[j],i] < 0:
#       gen_true_binary_full[gen_idx[j],i] = 0
#     else:
#       gen_true_binary_full[gen_idx[j],i] = profit_true[gen_idx[j],i]

## nodal injection
# gen_limit0 = x[:,2,:].copy()
for i in range(n_sample):
  for j in range(len(gen_idx)):
    # predicted generator limit
    if profit_pred[gen_idx[j],i] > binary_thres[gen_idx[j],i]:
      gen_pred_binary_full[gen_idx[j],i] = binary_thres[gen_idx[j],i]
    elif profit_pred[gen_idx[j],i] < binary_thres_lo[gen_idx[j],i]:
      gen_pred_binary_full[gen_idx[j],i] = binary_thres_lo[gen_idx[j],i]
    else:
      gen_pred_binary_full[gen_idx[j],i] = profit_pred[gen_idx[j],i]
    # true generator limit
    if profit_true[gen_idx[j],i] > binary_thres[gen_idx[j],i]:
      gen_true_binary_full[gen_idx[j],i] = binary_thres[gen_idx[j],i]
    elif profit_true[gen_idx[j],i] < binary_thres_lo[gen_idx[j],i]:
      gen_true_binary_full[gen_idx[j],i] = binary_thres_lo[gen_idx[j],i]
    else:
      gen_true_binary_full[gen_idx[j],i] = profit_true[gen_idx[j],i]


# injection by generators
# gen_inj = np.multiply(gen_pred_binary_full,gen_limit0)
# gen_inj_true = np.multiply(gen_true_binary_full,gen_limit0)
gen_inj=gen_pred_binary_full
gen_inj_true=gen_true_binary_full
# nodal injection
load0 = -x[:,1,:].copy() # load file
p_inj = gen_inj #- load0
p_inj_true = gen_inj_true #- load0

# %%
# load0 = x[:,0,:].copy()
print(np.sum(p_inj),np.sum(gen_inj_true))
print(np.sum(p_inj),np.sum(load0),np.sum(gen_inj))
# Out:
# 96481195.41301994 96574282.20502195
# 96481195.41301994 672765727.1314702 96481195.41301994

# %% [markdown]
# ## injection accuracy

# %%
print(p_inj_true.shape,p_inj.shape)

p_inj_true_sort = np.reshape(p_inj_true,n_bus*n_sample)
p_inj_sort = np.reshape(p_inj,n_bus*n_sample)

p_err = np.zeros(n_sample)
for i in range(n_sample):
  p_err[i] = np.linalg.norm(p_inj_true[:,i]-p_inj[:,i]) / np.linalg.norm(p_inj_true[:,i])

print('mean p_inj l2 err:',np.mean(p_err))
fig3 = plt.figure(figsize=(16, 8))
plt.subplot(1,2,1)
plt.hist(p_inj_sort, bins = 50, facecolor='b', alpha=0.75,label = 'pred. injection')
plt.hist(p_inj_true_sort, bins = 50, facecolor='g', alpha=0.75,label = 'true injection')
plt.legend(loc="upper right")
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('injection histogram')
plt.subplot(1,2,2)
plt.hist(p_err, bins = 50, facecolor='b', alpha=0.75,label = 'injection err')
plt.legend(loc="upper right")
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('error histogram')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.grid(True)
plt.show()
# Out:
# (1354, 9031) (1354, 9031)
# mean p_inj l2 err: 0.03515540170299178

# %% [markdown]
# * Calculate flow

# %%
filename=root+'data_1354ac_2022/ieee1354_fmax.txt'
f_max1=pd.read_table(filename,sep=',',header=None).to_numpy() # flow limit

n_line = np.size(S_isf,0)
flow_est = np.zeros((n_line,n_sample))
flow_est0 = np.zeros((n_line,n_sample))

f_binary = np.zeros((n_line,n_sample))
f_binary0 = np.zeros((n_line,n_sample))

# for i in range(n_sample):
flow_est = np.dot(S_isf,p_inj)
flow_est0 = np.dot(S_isf,p_inj_true)
# f_max
# f_max_numpy = f_max.cpu().detach().numpy()
f_max_numpy = f_max1.copy()
f_binary = (np.abs(flow_est)-f_max_numpy > 0)
f_binary0 = (np.abs(flow_est0)-f_max_numpy > 0)

# %%
print(f_max_numpy.shape,flow_est.shape,flow_est0.shape)
# Out:
# (1991, 1) (1991, 9031) (1991, 9031)

# %%
f_tot_sample = n_line * n_sample
print(np.sum(f_binary),np.sum(f_binary0))
print(np.sum(f_binary)/f_tot_sample,np.sum(f_binary0)/f_tot_sample)
# Out:
# 265801 267392
# 0.014782555160051702 0.014871038819856

# %%
print(n_line,n_sample,flow_est.shape)
# Out:
# 1991 9031 (1991, 9031)

# %%
# soft threshold
f_err_est = np.abs(flow_est)-f_max_numpy
f_err_true = np.abs(flow_est0)-f_max_numpy

f_err_est = np.maximum(np.abs(flow_est)-f_max_numpy,0) # identify violations
f_err_true = np.maximum(np.abs(flow_est0)-f_max_numpy,0)

print(np.max(f_err_est),np.max(f_err_true))
print(np.max(f_err_est/f_max_numpy),np.max(f_err_true/f_max_numpy))

# a= np.asarray([[1,2,1],[2,2,1]])
# b = np.asarray([1,1,1])
# c = (a-b>0)
# print(c)
# print(np.sum(c))
# Out:
# 648.1169677908488 547.0
# 0.6573194399501509 0.6412661195779601

# %%
np.min(f_max_numpy)
# Out:
# 281.0

# %%
# f_binary_soft = (np.abs(flow_est)-f_max_numpy > 0.01*np.max(f_max_numpy))
# f_binary0_soft = (np.abs(flow_est0)-f_max_numpy > 0.01*np.max(f_max_numpy))
f_binary_soft = (np.abs(flow_est)-f_max_numpy > 0.1*(f_max_numpy))
f_binary0_soft = (np.abs(flow_est0)-f_max_numpy > 0.1*(f_max_numpy))
print(np.sum(f_binary_soft),np.sum(f_binary0_soft))
print(np.sum(f_binary_soft)/f_tot_sample,np.sum(f_binary0_soft)/f_tot_sample)
# Out:
# 144048 147149
# 0.008011247157441573 0.008183709652132415

# %%
f_pred_sort = np.reshape(f_err_est/f_max_numpy,n_line*n_sample)
f_true_sort = np.reshape(f_err_true/f_max_numpy,n_line*n_sample)

fig2 = plt.figure(figsize=(16, 8))
plt.subplot(1,2,1)
plt.hist(f_pred_sort, bins = 10, facecolor='b', alpha=0.75,label = 'pred. f')
plt.hist(f_true_sort, bins = 10, facecolor='g', alpha=0.75,label = 'true f')
plt.legend(loc="upper right")
plt.xlabel('percentage')
plt.ylabel('frequency')
plt.title('flow violation level histogram')
plt.subplot(1,2,2)
plt.hist(f_true_sort, bins = 10, facecolor='g', alpha=0.75,label = 'true f')
plt.legend(loc="upper right")
plt.xlabel('percentage')
plt.ylabel('frequency')
plt.title('flow violation level histogram')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.grid(True)
plt.show()

# %%
f_line = np.sum(f_binary,0)
f_samp = np.sum(f_binary,1)
print('max sample pred:',np.max(f_line))
print('max line pred:',np.max(f_samp))

f_line0  = np.sum(f_binary0,0)
f_samp0 = np.sum(f_binary0,1)
print('max sample true:',np.max(f_line0))
print('max line true:',np.max(f_samp0))
# Out:
# max sample pred: 42
# max line pred: 9031
# max sample true: 41
# max line true: 9031

# %% [markdown]
# # Check objective optimality

# %%
# gen_pred_binary_full = np.zeros((n_bus,n_sample))
# gen_true_binary_full = np.zeros((n_bus,n_sample))

# p_inj = gen_inj #- load0
# p_inj_true = gen_inj_true #- load0

# gen_cost0 = x[:,4,:].copy()
# # lmp_data = y.copy()

# quadratic_a = x[:,5,:].copy()
print(gen_cost0.shape)
# Out:
# (1354, 9031)

# %%
gen_cost_pred = np.zeros((n_bus,n_sample))
gen_cost_true = np.zeros((n_bus,n_sample))
objective_err = np.zeros(n_sample)

gen_cost_pred = np.multiply(np.multiply(p_inj,p_inj),quadratic_a) + np.multiply(p_inj,gen_cost0)
gen_cost_true = np.multiply(np.multiply(p_inj_true,p_inj_true),quadratic_a) + np.multiply(p_inj_true,gen_cost0)

objective_err = np.sum(np.abs(gen_cost_true-gen_cost_pred),axis=0) / np.sum(gen_cost_true,axis=0)
print(np.mean(objective_err))

fig6 = plt.figure(figsize=(16, 8))
# error histogram
plt.hist(objective_err, bins = 50, facecolor='b', alpha=0.75,label = 'L2 error')
# plt.hist(err_linf_new, bins = 50, facecolor='g', alpha=0.75,label = 'Linf error')
plt.legend(loc="upper right")
plt.xlabel('sample error value')
plt.ylabel('frequency')
plt.title('Histogram of L_2 error')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.grid(True)
plt.show()
# Out:
# 0.047608661610069665

# %%
objective_err.shape
# Out:
# (9031,)

# %% [markdown]
# ## injection accuracy

# %%
print(p_inj_true.shape,p_inj.shape)

p_inj_true_sort = np.reshape(p_inj_true,n_bus*n_sample)
p_inj_sort = np.reshape(p_inj,n_bus*n_sample)

p_err = np.zeros(n_sample)
for i in range(n_sample):
  p_err[i] = np.linalg.norm(p_inj_true[:,i]-p_inj[:,i]) / np.linalg.norm(p_inj_true[:,i])

print('mean p_inj l2 err:',np.mean(p_err))
fig3 = plt.figure(figsize=(16, 8))
plt.subplot(1,2,1)
plt.hist(p_inj_sort, bins = 50, facecolor='b', alpha=0.75,label = 'pred. injection')
plt.hist(p_inj_true_sort, bins = 50, facecolor='g', alpha=0.75,label = 'true injection')
plt.legend(loc="upper right")
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('injection histogram')
plt.subplot(1,2,2)
plt.hist(p_err, bins = 50, facecolor='b', alpha=0.75,label = 'injection err')
plt.legend(loc="upper right")
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('error histogram')
# plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.grid(True)
plt.show()
# Out:
# (1354, 9031) (1354, 9031)
# mean p_inj l2 err: 0.03515540170299178

# %% [markdown]
# # Test AC feasibility
# * P in actual value, V in p.u.
# * Use P to recover $\theta$, or solve $\theta$ and Q for PF
# $$ Q_m = V_m \sum_{n=1}^N V_n \left(G_{mn}\sin\theta_{mn} - B_{mn}\cos\theta_{mn} \right) $$
# calculate $Q_{mn}$ directly

# %%
# p_inj (base all 100), p=B\theta, \theta_r = B_r^-1 p_r, ref bus is 69

# %%
# Bbus and B_r inverse
filename1 = root+'data_1354ac_2022/ieee1354_Bbus.txt'
Bbus=pd.read_table(filename1,sep=',',header=None).to_numpy()
B_r = np.delete(Bbus,639,axis=0)
B_r = np.delete(B_r,639,axis=1)

Br_inv = np.linalg.inv(B_r)

# Jacobian for fast decoupled power flow 
filename1 = root+'data_1354ac_2022/ieee1354_ieee1354_J1.txt'
J1=pd.read_table(filename1,sep=',',header=None).to_numpy()
# J1_r = np.delete(J1,639,axis=0) # already reduced
# J1_r = np.delete(J1_r,639,axis=1)
J1r_inv = np.linalg.inv(J1)

# nominal angle for fast decoupled power flow 
filename1 = root+'data_1354ac_2022/ieee1354_ieee1354_theta_nominal.txt'
theta_nominal=pd.read_table(filename1,sep=',',header=None).to_numpy()
# nominal injection for fast decoupled power flow 
filename1 = root+'data_1354ac_2022/ieee1354_ieee1354_pinj_nominal.txt'
pinj_nominal=pd.read_table(filename1,sep=',',header=None).to_numpy()


# line parameters
filename1 = root+'data_1354ac_2022/ieee1354_lineloc.txt'
line_loc = pd.read_table(filename1,sep=',',header=None).to_numpy()
# line_entry_loc = np.nonzero(G_mat) # index of nonzero entries
# # not in p.u.
# G_line = np.zeros(n_line)
# B_line = np.zeros(n_line)

# # print(line_loc.shape) #[186,2]
# for i in range(n_line):
#   G_line[i] = G_mat[line_loc[i,0]-1,line_loc[i,1]-1]
#   B_line[i] = B_mat[line_loc[i,0]-1,line_loc[i,1]-1]

# load line params
filename1 = root+'data_1354ac_2022/ieee1354_lineparams_tap.txt'
line_params = pd.read_table(filename1,sep=',',header=None).to_numpy()

n_line = 1751 # the rest are transformers
line_loc = line_loc[:n_line,:].copy()
line_params = line_params[:n_line,:].copy()

# filename2 = 'data_1354ac_2022/ieee1354_Ybus.txt'
# Y_bus = pd.read_table(filename2,sep=',',header=None).to_numpy()

# G_line = line_params[:,0].copy()
# B_line = line_params[:,1].copy()
R_line = line_params[:,0].copy()
X_line = line_params[:,1].copy()

B_shunt = line_params[:,2].copy()

Z_line = R_line + 1j * X_line 
Y_line = 1 / Z_line

G_line = np.real(Y_line)
B_line = np.imag(Y_line)

# transformer indicator
# a = R_line > 0
a = np.ones(n_line)
a=torch.from_numpy(a)
G_line=torch.from_numpy(G_line)
B_line=torch.from_numpy(B_line)
B_shunt=torch.from_numpy(B_shunt)

# P_inj w/out reference bus in p.u.
p_inj_r = np.delete(p_inj,639,axis=0) / 100
p_inj_true_r = np.delete(p_inj_true,639,axis=0) / 100

p_inj_pu = p_inj / 100
p_inj_true_pu = p_inj_true / 100

# print(Br_inv.shape,p_inj.shape,p_inj_true.shape)#p_inj_true
print(J1r_inv.shape,p_inj.shape,p_inj_true.shape)
print(J1r_inv.shape,p_inj_r.shape,pinj_nominal.shape)

# calculate angle (w/our reference at 640th node)
# theta0 = np.matmul(Br_inv,p_inj_r)
# theta_true0 = np.matmul(Br_inv,p_inj_true_r)
theta0 = np.matmul(J1r_inv,p_inj_r-pinj_nominal)
theta_true0 = np.matmul(J1r_inv,p_inj_true_r-pinj_nominal)

theta = np.insert(theta0,639,0,axis = 0)
theta_true = np.insert(theta_true0,639,0,axis = 0)
# restore from deviation
theta = theta + theta_nominal/180*math.pi
theta_true = theta_true + theta_nominal/180*math.pi

# filename1 = '/content/drive/MyDrive/gnn/data/data_118_quad/ieee118_ac_10000_theta.txt'
# theta = pd.read_table(filename1,sep=',',header=None).to_numpy()
# theta = theta / 180 * math.pi

print(theta.shape,theta_true.shape)
# Out:
# (1353, 1353) (1354, 9031) (1354, 9031)
# (1353, 1353) (1353, 9031) (1353, 1)
# (1354, 9031) (1354, 9031)

# %%
# print(theta_true0)
# print('deviation')
# print(theta0-theta_true0)
print(np.matmul(J1r_inv,p_inj_r-pinj_nominal))
# Out:
# [[0.40268325 0.34751837 0.4146436  ... 0.48154593 0.449904   0.54103567]
#  [0.24740099 0.22048035 0.26524685 ... 0.33568209 0.26209572 0.31161893]
#  [0.44951185 0.41824756 0.45872876 ... 0.5214666  0.52982981 0.64861211]
#  ...
#  [0.52506215 0.49513746 0.61657876 ... 0.74642963 0.62269232 0.71649557]
#  [0.41887552 0.40167471 0.42944883 ... 0.48535231 0.47557864 0.606894  ]
#  [0.55874736 0.45900657 0.50870058 ... 0.58770039 0.60119612 0.707013  ]]

# %%
for i in range(5):
  print(G_line[i],B_line[i])
# Out:
# tensor(280.2163, dtype=torch.float64) tensor(-1215.8272, dtype=torch.float64)
# tensor(10.3055, dtype=torch.float64) tensor(-58.0878, dtype=torch.float64)
# tensor(29.5110, dtype=torch.float64) tensor(-227.6560, dtype=torch.float64)
# tensor(32.8321, dtype=torch.float64) tensor(-403.8348, dtype=torch.float64)
# tensor(20.9748, dtype=torch.float64) tensor(-263.5829, dtype=torch.float64)

# %%
print(np.max(theta),np.min(theta))
# math.sin(math.pi/6)
print(G_line[0],B_line[0])


# print(Y_bus.shape,line_loc.shape,G_line.shape,n_line)

# G_line1 = np.zeros(n_line)
# B_line1 = np.zeros(n_line)

# for i in range(2):
#   Y_temp = Y_bus[line_loc[i,0]-1,line_loc[i,1]-1]
#   Y_temp = Y_temp.replace('i','j')
#   Y_temp = complex(Y_temp)
#   # print(type(Y_temp))
#   # print(Y_temp,np.real(Y_temp),np.imag(Y_temp))
#   G_line1[i] = np.real(Y_temp)
#   B_line1[i] = np.imag(Y_temp)

# G_line = G_line1
# B_line = B_line1
# Out:
# 1.013134654183831 -0.9998535483844071
# tensor(280.2163, dtype=torch.float64) tensor(-1215.8272, dtype=torch.float64)

# %%
print(type(G_line))
print(np.max(y_pred1[:,1,:]),np.min(y_pred1[:,1,:]))
print(np.max(theta),np.min(theta))
print(math.sin(math.pi/6))
# Out:
# <class 'torch.Tensor'>
# 307.7652587890625 189.6956787109375
# 1.013134654183831 -0.9998535483844071
# 0.49999999999999994

# %%
# B_line
import math

# n_sample1 = 500
n_sample1 = n_sample
f_tot_sample1 = n_line*n_sample1

# load true voltage file
filename1 = root+'data_1354ac_2022/ieee1354pegase_ac_9974_cases_v_04022022.txt'
v_true = pd.read_table(filename1,sep=',',header=None).to_numpy()
print(v_true.shape)

# load true theta file
filename2 = root+'data_1354ac_2022/ieee1354pegase_ac_9974_cases_theta_04022022.txt'
theta_true = pd.read_table(filename2,sep=',',header=None).to_numpy()
# theta_true = theta_true / 180 * math.pi
print(theta_true)
print(theta_true.shape)

v_true = np.delete(v_true, del_idx,axis=1)
theta_true = np.delete(theta_true, del_idx,axis=1)
print(v_true.shape,theta_true.shape)
# Out:
# (1354, 9974)
# [[-19.085   -19.996   -17.394   ... -17.016   -18.041   -18.042  ]
#  [ -1.5689   -1.689    -1.0069  ...  -0.33903  -0.99374  -2.4735 ]
#  [-44.41    -44.106   -43.909   ... -44.498   -43.883   -44.796  ]
#  ...
#  [-31.162   -25.654   -26.204   ... -26.987   -27.145   -29.515  ]
#  [-35.832   -34.86    -35.009   ... -35.492   -35.535   -35.59   ]
#  [-26.664   -28.941   -28.263   ... -28.603   -28.076   -29.286  ]]
# (1354, 9974)
# (1354, 9031) (1354, 9031)

# %%
# print(theta)
# print('')
# print(theta_true)
v_pred = y_pred1[:,1,:].copy()
v_pred = v_pred / vy_scale + vy_deviation
print(v_pred)
print('')
print(v_true)
# Out:
# [[1.07112988 1.0709856  1.07127664 ... 1.0712395  1.07109839 1.07117047]
#  [1.07132462 1.07117206 1.07146436 ... 1.07142474 1.07130209 1.07135815]
#  [1.06866281 1.06838214 1.06869531 ... 1.06861963 1.06876288 1.06856754]
#  ...
#  [1.07928638 1.07908368 1.07941177 ... 1.0793584  1.07929428 1.07928857]
#  [1.05601297 1.0558573  1.05609952 ... 1.05605753 1.0560303  1.05601443]
#  [1.07431226 1.07378333 1.07418079 ... 1.07403818 1.07460828 1.07398016]]
#
# [[1.0692 1.0699 1.0721 ... 1.0775 1.0751 1.0734]
#  [1.0702 1.0707 1.0696 ... 1.071  1.0713 1.0716]
#  [1.0707 1.0625 1.0666 ... 1.0694 1.07   1.0716]
#  ...
#  [1.0847 1.084  1.0788 ... 1.0595 1.0699 1.0705]
#  [1.0537 1.0556 1.0558 ... 1.0567 1.0557 1.0581]
#  [1.0786 1.0571 1.0616 ... 1.0613 1.0684 1.0854]]

# %%
# Calculate real and reactive flow
f_p = np.zeros((n_line,n_sample1))
f_q = np.zeros((n_line,n_sample1))
fji_p = np.zeros((n_line,n_sample1))
fji_q = np.zeros((n_line,n_sample1))
print(f_q.shape)

v_pred = y_pred1[:,1,:].copy()
v_pred = v_pred / vy_scale + vy_deviation

# v_pred = v_true.copy()
# theta = theta_true.copy()

print(np.max(v_pred),np.min(v_pred),v_pred.shape)

theta1 = theta[line_loc[:,0]-1,:]
theta2 = theta[line_loc[:,1]-1,:]
V1 = torch.from_numpy(v_pred[line_loc[:,0]-1,:]).double()
V2 = torch.from_numpy(v_pred[line_loc[:,1]-1,:]).double() 
theta1=torch.from_numpy(theta1)
theta2=torch.from_numpy(theta2)

f_p=(a*G_line*(V1*V1).T)-a*((V1*V2).T)*(G_line*torch.cos(theta1-theta2).T+B_line*torch.sin(theta1-theta2).T)
f_p=f_p.T
f_q=-a*(V1.T)*(a*V1.T)*(B_line+B_shunt/2)+a*((V1*V2).T)*(B_line*torch.cos(theta1-theta2).T-G_line*torch.sin(theta1-theta2).T)
f_q=f_q.T

theta1 = theta[line_loc[:,1]-1,:]
theta2 = theta[line_loc[:,0]-1,:]
V1 = torch.from_numpy(v_pred[line_loc[:,1]-1,:]).double()
V2 = torch.from_numpy(v_pred[line_loc[:,0]-1,:]).double()
theta1=torch.from_numpy(theta1)
theta2=torch.from_numpy(theta2)

fji_p=(a*G_line*(V1*V1).T)-a*((V1*V2).T)*(G_line*torch.cos(theta1-theta2).T+B_line*torch.sin(theta1-theta2).T)
fji_p=fji_p.T
fji_q=-a*(V1.T)*(a*V1.T)*(B_line+B_shunt/2)+a*((V1*V2).T)*(B_line*torch.cos(theta1-theta2).T-G_line*torch.sin(theta1-theta2).T)
fji_q=fji_q.T

# for i in range(n_line):
#   for j in range(n_sample1):
#     f_p[i,j] = a[i] * v_pred[line_loc[i,0]-1,j] * v_pred[line_loc[i,0]-1,j] * G_line[i] \
#              - (a[i] * v_pred[line_loc[i,0]-1,j]) * v_pred[line_loc[i,1]-1,j] \
#              * (G_line[i] * math.cos(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]) \
#               + B_line[i] * math.sin(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]))
#     f_q[i,j] =-(a[i] * v_pred[line_loc[i,0]-1,j]) **2 * (B_line[i] + B_shunt[i]/2) \
#              + a[i] * v_pred[line_loc[i,0]-1,j] * v_pred[line_loc[i,1]-1,j] \
#              * (B_line[i] * math.cos(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]) \
#               - G_line[i] * math.sin(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]))
             
#     fji_p[i,j] = a[i] * v_pred[line_loc[i,1]-1,j] * v_pred[line_loc[i,1]-1,j] * G_line[i] \
#              - (a[i] * v_pred[line_loc[i,1]-1,j]) * v_pred[line_loc[i,0]-1,j] \
#              * (G_line[i] * math.cos(theta[line_loc[i,1]-1,j] - theta[line_loc[i,0]-1,j]) \
#               + B_line[i] * math.sin(theta[line_loc[i,1]-1,j] - theta[line_loc[i,0]-1,j]))
#     fji_q[i,j] =-(a[i] * v_pred[line_loc[i,1]-1,j]) **2 * (B_line[i] + B_shunt[i]/2) \
#              + a[i] * v_pred[line_loc[i,1]-1,j] * v_pred[line_loc[i,0]-1,j] \
#              * (B_line[i] * math.cos(theta[line_loc[i,1]-1,j] - theta[line_loc[i,0]-1,j]) \
#               - G_line[i] * math.sin(theta[line_loc[i,1]-1,j] - theta[line_loc[i,0]-1,j]))
# Out:
# (1751, 9031)
# 1.1077652587890625 0.9896956787109376 (1354, 9031)

# %%
print('mean p_ij,q_ij:',torch.mean(f_p),torch.mean(f_q))
print('mean p_ji,q_ji:',torch.mean(fji_p),torch.mean(fji_q))
# print(f_q)
# Out:
# mean p_ij,q_ij: tensor(-0.0002, dtype=torch.float64) tensor(0.0524, dtype=torch.float64)
# mean p_ji,q_ji: tensor(0.0109, dtype=torch.float64) tensor(0.0490, dtype=torch.float64)

# %%
theta = theta_true.copy()
print('Scale check:')
i=0;j=0
# a[0] = 1
a = np.ones(1751)
print('G,B,loc:',G_line[i],B_line[i],line_loc[i,0]-1,line_loc[i,1]-1) # G,B,line_loc verified
print('v:',v_pred[line_loc[i,0]-1,j],v_pred[line_loc[i,1]-1,j]) # v verified
print('theta:',theta[line_loc[i,0]-1,j],theta[line_loc[i,1]-1,j]) # theta verified
print('p,q:',f_p[0,0],f_q[0,0],fji_p[i,j],fji_q[i,j])


f_p_test = a[i] * v_pred[line_loc[i,0]-1,j] * v_pred[line_loc[i,0]-1,j] * G_line[i] \
             - (a[i] * v_pred[line_loc[i,0]-1,j]) * v_pred[line_loc[i,1]-1,j] \
             * (G_line[i] * math.cos(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]) \
              + B_line[i] * math.sin(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]))
             
f_q_test =-(a[i] * v_pred[line_loc[i,0]-1,j]) **2 * (B_line[i] + B_shunt[i]/2) \
             + a[i] * v_pred[line_loc[i,0]-1,j] * v_pred[line_loc[i,1]-1,j] \
             * (B_line[i] * math.cos(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]) \
              - G_line[i] * math.sin(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]))
             
print('test p/q:',f_p_test,f_q_test)
# Out:
# Scale check:
# G,B,loc: tensor(280.2163, dtype=torch.float64) tensor(-1215.8272, dtype=torch.float64) 1073 801
# v: 1.0878158264160156 1.0880387268066407
# theta: -19.014 -18.995
# p,q: tensor(-0.5502, dtype=torch.float64) tensor(-0.1836, dtype=torch.float64) tensor(0.5502, dtype=torch.float64) tensor(0.1838, dtype=torch.float64)
# test p/q: tensor(-27.3481, dtype=torch.float64) tensor(6.2661, dtype=torch.float64)

# %%
print(a[i],v_pred[line_loc[i,0]-1,j],B_line[i] + B_shunt[i]/2,v_pred[line_loc[i,1]-1,j])
print(G_line[i],math.cos(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]),math.sin(theta[line_loc[i,0]-1,j] - theta[line_loc[i,1]-1,j]))
# Out:
# 1.0 1.0878158264160156 tensor(-1215.8272, dtype=torch.float64) 1.0880387268066407
# tensor(280.2163, dtype=torch.float64) 0.9998195054299763 -0.018998856853965667

# %%
# Calculate apparent power
# s_pred = np.zeros((n_line,n_sample1))
# sji_pred = np.zeros((n_line,n_sample1))

# for i in range(n_line):
#   for j in range(n_sample1):
#     # s_pred[i,j] = np.sqrt(flow_est[i,j]**2 + f_q[i,j]**2)
#     s_pred[i,j] = np.sqrt(f_p[i,j]**2 + f_q[i,j]**2)
#     sji_pred[i,j] = np.sqrt(fji_p[i,j]**2 + fji_q[i,j]**2)

s_pred = torch.sqrt(f_p*f_p+f_q*f_q)*100
sji_pred = torch.sqrt(fji_p*fji_p+fji_q*fji_q)*100
# s_pred = s_pred * 100 # p.u. to mva
# sji_pred = sji_pred * 100 # p.u. to mva

# %%
# np.max(y_pred1[:,1,:]/100+0.8)

f_p = f_p.numpy();f_q = f_q.numpy()
s_pred = s_pred.numpy();sji_pred = sji_pred.numpy()

print(np.max(f_q),np.min(f_q))
flow_est.shape

print(np.mean(s_pred[0,:]),np.mean(f_max_numpy[0]))
# Out:
# 5.782055905684842 -4.481364451232679
# 65.83333051698493 39412.0

# %%
sij_binary = (np.abs(s_pred)-f_max_numpy[:n_line] > 0)
sji_binary = (np.abs(sji_pred)-f_max_numpy[:n_line] > 0)
s_binary = np.maximum(sij_binary,sji_binary)

# sij_binary0 = (np.abs(flow_est0)-f_max_numpy > 0)
print(np.sum(s_binary))#,np.sum(f_binary0))
print('hard violation rate:',np.sum(s_binary)/f_tot_sample1)#,np.sum(f_binary0)/f_tot_sample)

s_binary_soft = (np.abs(s_pred)-f_max_numpy[:n_line] > 0.1*(f_max_numpy[:n_line]))
# s_binary0_soft = (np.abs(flow_est0)-f_max_numpy > 0.1*(f_max_numpy))
print(np.sum(s_binary_soft))#,np.sum(f_binary0_soft))
print(np.sum(s_binary_soft)/f_tot_sample1)#,np.sum(f_binary0_soft)/f_tot_sample)
# Out:
# 298950
# hard violation rate: 0.0189049951113877
# 166510
# 0.010529756601428887

# %%
# violation level
sij_violation = np.abs(s_pred)-f_max_numpy[:n_line] #/ f_max_numpy
sij_violation_level = np.maximum(sij_violation,0)
sji_violation = np.abs(sji_pred)-f_max_numpy[:n_line] #/ f_max_numpy
sji_violation_level = np.maximum(sji_violation,0)

s_violation_level = np.maximum(sij_violation_level,sji_violation_level)

s_violation_level = np.divide(s_violation_level,f_max_numpy[:n_line])
s_vio_lvl = np.reshape(s_violation_level,n_line*n_sample1)

print('S violation level:')
print('hard:',np.sum(s_binary)/f_tot_sample1)
print('mean:',np.mean(s_vio_lvl))
print('median:',np.median(s_vio_lvl))
print('max:',np.max(s_vio_lvl))
print('std:',np.std(s_vio_lvl))
print('p99:',np.percentile(s_vio_lvl,99))

f_violation = np.abs(flow_est)-f_max_numpy #/ f_max_numpy
f_violation_level = np.maximum(f_violation,0)
f_violation_level = np.divide(f_violation_level,f_max_numpy)
f_vio_lvl = np.reshape(f_violation_level,1991*n_sample)

print('f violation level:')
print('hard:',np.sum(f_binary)/f_tot_sample,np.sum(f_binary0)/f_tot_sample)
print('mean:',np.mean(f_vio_lvl))
print('median:',np.median(f_vio_lvl))
print('max:',np.max(f_vio_lvl))
print('std:',np.std(f_vio_lvl))
print('p99:',np.percentile(f_vio_lvl,99))

fig4 = plt.figure(figsize=(6,4))
plt.hist(s_vio_lvl, bins = 50, facecolor='b', alpha=0.75,label = 's violation')
plt.hist(f_vio_lvl, bins = 50, facecolor='r', alpha=0.75,label = 'f violation')
plt.legend(loc="upper right")
plt.xlabel('violation level')
plt.ylabel('frequency')
# plt.title('injection histogram')
plt.show()
# Out:
# S violation level:
# hard: 0.0189049951113877
# mean: 0.0035683960030774096
# median: 0.0
# max: 0.8771357214594202
# std: 0.035519545021570065
# p99: 0.11631638680101837
# f violation level:
# hard: 0.014782555160051702 0.014871038819856
# mean: 0.0022880847147270273
# median: 0.0
# max: 0.6573194399501509
# std: 0.024986536267470202
# p99: 0.06574133282235083

# %%
# err_L2_mean = np.mean(err_L2)
# err_Linf_mean = np.mean(err_Linf)
print('Price L2 mean:', err_L2_mean,'L_inf mean:', err_Linf_mean )
print('std:',np.std(err_L2))
# err_L2_mean_v = np.mean(err_L2_v)
# err_Linf_mean_v = np.mean(err_Linf_v)
print('Voltage L2 mean:', err_L2_mean_v,'L_inf mean:', err_Linf_mean_v )
print('std:',np.std(err_L2_v))
# Out:
# Price L2 mean: 0.036446683532038164 L_inf mean: 0.11858167578348175
# std: 0.014218393253231652
# Voltage L2 mean: 0.005478581595742231 L_inf mean: 0.03026995133636676
# std: 0.0016454066008872302

# %%
# np.max(s_violation_level)
# s_violation_level[:,0]
# print(s_pred[:,0])
# print(f_max_numpy)

# %%
# # solve for Q
# from scipy.optimize import fsolve

# # print(np.max(theta*180/2/math.pi),np.max(theta_true*180/2/math.pi))

# def PF_eq(Q,V,G_mat,B_mat,n_bus,line_loc):
#   PF_obj = [None]*n_bus
#   for i in range(n_bus):
#     PF_obj[i] = 

#   return PF_obj

# line_loc = np.nonzero(G_mat) # index of nonzero entries
# root = fsolve(PF_eq, np.zeros(118, args=(y_pred1[:,1,:0],G_mat,B_mat,n_bus,line_loc))
